# %%
import re
from rdkit import Chem

# %%
inputfile = """C
AR 
A1 
A1- 
A1C2H 
A1C2H-M
A1CH2 
A1CH2OH 
A1CH3 
A1CHO 
A1CO 
C-2-C4H8 
CYC6H4 
CH2CH2COCH3
C2H 
C2H2 
C2H3 
C2H4 
C2H4O1-2
C2H4O2H
C2H5 
C2H5CHO
C2H5CO
C2H5COCH2
C2H5O 
C2H5OH 
C2H5O2
C2H5O2H
C2H6 
C2O 
C3H2 
C3H3 
C3H4 
C3H4P 
C3H5 
C3H6 
C3H6CHO-1
C3H6COCH3-1
C3H8 
C4H 
C4H10 
C4H2 
C4H4 
C4H6 
C4H612 
C4H8-1 
C4H8-2 
C4H9-1 
C4H9-2 
C5H2 
C5H3 
OCYC5H4 
OHCYC5H4- 
CYC5H5- 
OCYC5H5 
CYC5H6
I-A-C5H10
I-A-C5H9P
I-A-C5H9S
I-A-C5H8
C6H 
C6H10 
C6H2 
C6H3 
C6H4-1 
OA1 
OHA1 
C6H6-1 
C6H8 
C6H9-1 
C6H9-2 
CH 
CH2-1 
CH2-3 
CH2CH2OH
CH2CH2CHO 
CH2CHO 
CH2CO 
CH2O 
CH2OH 
CH3 
CH3CHO 
CH3CHCO
CH3CHOH 
CH3CO 
CH3O 
CH3O2 
CH3O2H 
CH3OH 
CH4 
CO 
CO2 
H 
H2 
H2C4O 
H2O 
H2O2 
HCCO 
HCO 
HO2 
HO2CHO
HOCHO
HOCH2O
OHA1CH3-O 
I-C3H7 
N-C3H7CO
N-C3H7CHO
I-C4H3 
I-C4H5 
I-C4H9 
I-C4H10 
I-C6H5 
I-C6H7 
N-C3H7 
N-C3H7O
N-C3H7O2
N-C3H7O2H
N-C4H3 
N-C4H5 
N-C6H7 
O 
O2 
O2CHO
OCHO
OA1CH3-O 
OH 
TOLA2 
N-C6H5 
C-C6H7 
A1C2H2-R1 
A1C2H2-R2 
A1C2H-O 
N2 
C3H5O 
C2H3CHO 
T-C4H9 
CH3CO3 
CH3CO3H
I-C3H7O 
I-C3H7O2 
I-C3H7O2H 
I-C4H9O2 
I-C4H9O2H 
T-C4H9O2 
T-C4H9O2H 
I-C4H8 
I-C4H9O 
I-C3H7CHO 
I-C4H7 
C2H3CO 
CH3CO2 
T-C4H9O 
I-C4H7O 
I-C4H8O2H-I 
I-C4H8O2H-T 
CC4H8O 
I-C4H8O 
C3H5-T 
I-C4H7OH 
I-C3H5CHO 
CH3COCH2 
I-C4H6OH 
I-C4H7CO 
CH3COCH3 
I-C3H5CO 
T-C3H6OH 
T-C4H8O2H-I 
I-C4H8OH 
IO2C4H8OH 
# !Soot
A1C2HAC
A2
A2-X
A2R5
A2R5-
A2R5C2H
A3R5
A3R5-
ANC2HAC
A2R5C2H-
A1CH3-M
OA1CH3-M
OHA1CH3-M
A1M1OH3-
C5H11-1
C4H7P-1
C4H7S-1 
FC6H6 !Fulvene 
!---------------------------------------------------------!
# !cylohexane Species
!---------------------------------------------------------!
CYC6H11       
CYC6H10       
CYC6H9
CYC6H8
CYC6H7
CYC6H12       
!---------------------------------------------------------!
!1-hexene species
!---------------------------------------------------------!
C4H5O-D1K4R4
C4H5O-D1K3R4
C4H6O-D1K3
C4H6O-D1K4
C5H7-D1D4R3
C5H7O-D1K3R5
C5H7O-D1K5R5
C5H7O-D1K4R5
C5H8-D1D3       
C5H8-D1D4
C5H8O-D1K5
C5H9-D1R3
C5H9-D1R4
C5H9-D1R5
C5H10-1  
C5H10-2       
C5H11-2 
C5H11-3 
C6H9-D1D3R6
C6H9-D1D3R5
C6H9-D1D5R3
C6H10-D1D3
C6H10-D1D4
C6H10O-D1E45
C6H10O-D1E35
C6H10O-D1E34
C6H10O-D1E36
C6H10O-D1E46
C6H10O-D1E56
C6H10O3-D1K3HP4
C6H10O3-D1K3HP5
C6H10O3-D1K3HP6
C6H10O3-D1K4HP3
C6H10O3-D1K4HP5
C6H10O3-D1K4HP6
C6H10O3-D1K5HP3
C6H10O3-D1K5HP4 
C6H10O3-D1K5HP6 
C6H10O3-D1K6HP3
C6H10O3-D1K6HP4
C6H10O3-D1K6HP5
C6H11-D1R3
C6H11-D1R4
C6H11-D1R5
C6H11-D1R6
C6H11O-D1O3
C6H11O-D1O4
C6H11O-D1O5
C6H11O-D1O6
C6H11O2-D1P3
C6H11O2-D1P4
C6H11O2-D1P5
C6H11O2-D1P6
C6H11O2-D1HP3R4
C6H11O2-D1HP3R5
C6H11O2-D1HP3R6
C6H11O2-D1HP4R3
C6H11O2-D1HP4R5
C6H11O2-D1HP4R6
C6H11O2-D1HP5R3 
C6H11O2-D1HP5R4
C6H11O2-D1HP5R6 
C6H11O2-D1HP6R3
C6H11O2-D1HP6R4
C6H11O2-D1HP6R5
C6H11O2H-D1HP3
C6H11O2H-D1HP4  
C6H11O2H-D1HP5
C6H11O2H-D1HP6
C6H11O4-D1HP3P4 
C6H11O4-D1HP3P5
C6H11O4-D1HP3P6
C6H11O4-D1HP4P3
C6H11O4-D1HP4P5
C6H11O4-D1HP4P6
C6H11O4-D1HP5P3
C6H11O4-D1HP5P4
C6H11O4-D1HP5P6
C6H11O4-D1HP6P3
C6H11O4-D1HP6P4
C6H11O4-D1HP6P5
C6H12-d1     
"""

# %%
inputfile.split()
name = inputfile.split()
name = [x for x in name if "!" not in x]  # gets rid of entries with !
name = [x for x in name if "pecies" not in x]  # gets rid of the word species
#print name
#len(name)

# %%
raw_smiles = name
smiles = {}
for n in range(0, len(name)):
    s = raw_smiles[n]
    s = re.sub('A1-', '[C]1CCCCC1', s)
    s = re.sub('A1', 'C1CCCCC1', s)
    s = re.sub('AR', 'Ar', s)
    s = re.sub('CH3', '[CH3]', s)
    s = re.sub('CH4', 'C', s)
    s = re.sub('C2H ', '[C]#C', s)
    s = re.sub('CH2', '[CH2]', s)
    s = re.sub('CO2', 'O=C=O', s)
    s = re.sub('OH', 'O', s)
    s = re.sub('O1 ', 'O', s)
    s = re.sub('O2H', 'OO', s)
    s = re.sub('O2 ', '[O][O]', s)
    s = re.sub('O2', 'O[O]', s)
    s = re.sub('CHO ', 'C=O', s)
    s = re.sub('CO', 'O=[C]', s)
    s = re.sub('CH2', '[CH2]', s)
    s = re.sub('COCH2', '(=O)CC', s)
    s = re.sub('COCH3 ', 'CC(C)=O', s)
    s = re.sub('C2H2', 'C#C', s)
    s = re.sub('C2H3', '[CH]=C', s)
    s = re.sub('C2H4', 'C=C', s)
    s = re.sub('C2H5', 'C[CH2]', s)
    s = re.sub('A2', 'C1CCC2CCCCC2C1', s)
    s = re.sub('CHOH', '[CH]O', s)
    s = re.sub('HO2', '[O]O', s)
    
    s = re.sub('C2H6', 'CC', s)
    s = re.sub('C3H8', 'CCC', s)
    s = re.sub('-C4H10', 'CC(C)C', s)
    s = re.sub('C4H10', 'CCCC', s)
    
    
    #for x in range(1, 10):  # saturated hydrocarbons
    #    pattern = r'^C' + re.escape(x) + r'H' + re.escape(2*x+2)
    #    s = re.sub(pattern, 'C' * x, s)
    smiles[n] = s
    
a = smiles
a.items()
new_smiles = [(v,k) for (k,v) in a.iteritems()]
new_smiles = zip(*new_smiles)[0]
names = zip(name, new_smiles)
for line in names:
    print line
# Out:
# ('C', 'C')
# ('AR', 'Ar')
# ('A1', 'C1CCCCC1')
# ('A1-', '[C]1CCCCC1')
# ('A1C2H', 'C1CCCCC1C2H')
# ('A1C2H-M', 'C1CCCCC1C2H-M')
# ('A1CH2', 'C1CCCCC1[[CH2]]')
# ('A1CH2OH', 'C1CCCCC1[[CH2]]O')
# ('A1CH3', 'C1CCCCC1[CH3]')
# ('A1CHO', 'C1CCCCC1CHO')
# ('A1CO', 'C1CCCCC1O=[C]')
# ('C-2-C4H8', 'C-2-C4H8')
# ('CYC6H4', 'CYC6H4')
# ('CH2CH2COCH3', '[[CH2]][[CH2]]O=[C][CH3]')
# ('C2H', 'C2H')
# ('C2H2', 'C#C')
# ('C2H3', '[CH]=C')
# ('C2H4', 'C=C')
# ('C2H4O1-2', 'C=CO1-2')
# ('C2H4O2H', 'C=COO')
# ('C2H5', 'C[CH2]')
# ('C2H5CHO', 'C[CH2]CHO')
# ('C2H5CO', 'C[CH2]O=[C]')
# ('C2H5COCH2', 'C[CH2]O=[C][[CH2]]')
# ('C2H5O', 'C[CH2]O')
# ('C2H5OH', 'C[CH2]O')
# ('C2H5O2', 'C[CH2]O[O]')
# ('C2H5O2H', 'C[CH2]OO')
# ('C2H6', 'CC')
# ('C2O', 'C2O')
# ('C3H2', 'C3H2')
# ('C3H3', 'C3H3')
# ('C3H4', 'C3H4')
# ('C3H4P', 'C3H4P')
# ('C3H5', 'C3H5')
# ('C3H6', 'C3H6')
# ('C3H6CHO-1', 'C3H6CHO-1')
# ('C3H6COCH3-1', 'C3H6O=[C][CH3]-1')
# ('C3H8', 'CCC')
# ('C4H', 'C4H')
# ('C4H10', 'CCCC')
# ('C4H2', 'C4H2')
# ('C4H4', 'C4H4')
# ('C4H6', 'C4H6')
# ('C4H612', 'C4H612')
# ('C4H8-1', 'C4H8-1')
# ('C4H8-2', 'C4H8-2')
# ('C4H9-1', 'C4H9-1')
# ('C4H9-2', 'C4H9-2')
# ('C5H2', 'C5H2')
# ('C5H3', 'C5H3')
# ('OCYC5H4', 'OCYC5H4')
# ('OHCYC5H4-', 'OCYC5H4-')
# ('CYC5H5-', 'CYC5H5-')
# ('OCYC5H5', 'OCYC5H5')
# ('CYC5H6', 'CYC5H6')
# ('I-A-C5H10', 'I-A-C5H10')
# ('I-A-C5H9P', 'I-A-C5H9P')
# ('I-A-C5H9S', 'I-A-C5H9S')
# ('I-A-C5H8', 'I-A-C5H8')
# ('C6H', 'C6H')
# ('C6H10', 'C6H10')
# ('C6H2', 'C6H2')
# ('C6H3', 'C6H3')
# ('C6H4-1', 'C6H4-1')
# ('OA1', 'OC1CCCCC1')
# ('OHA1', 'OC1CCCCC1')
# ('C6H6-1', 'C6H6-1')
# ('C6H8', 'C6H8')
# ('C6H9-1', 'C6H9-1')
# ('C6H9-2', 'C6H9-2')
# ('CH', 'CH')
# ('CH2-1', '[[CH2]]-1')
# ('CH2-3', '[[CH2]]-3')
# ('CH2CH2OH', '[[CH2]][[CH2]]O')
# ('CH2CH2CHO', '[[CH2]][[CH2]]CHO')
# ('CH2CHO', '[[CH2]]CHO')
# ('CH2CO', '[[CH2]]O=[C]')
# ('CH2O', '[[CH2]]O')
# ('CH2OH', '[[CH2]]O')
# ('CH3', '[CH3]')
# ('CH3CHO', '[CH3]CHO')
# ('CH3CHCO', '[CH3]CHO=[C]')
# ('CH3CHOH', '[CH3]CHO')
# ('CH3CO', '[CH3]O=[C]')
# ('CH3O', '[CH3]O')
# ('CH3O2', '[CH3]O[O]')
# ('CH3O2H', '[CH3]OO')
# ('CH3OH', '[CH3]O')
# ('CH4', 'C')
# ('CO', 'O=[C]')
# ('CO2', 'O=C=O')
# ('H', 'H')
# ('H2', 'H2')
# ('H2C4O', 'H2C4O')
# ('H2O', 'H2O')
# ('H2O2', 'H2O[O]')
# ('HCCO', 'HCO=[C]')
# ('HCO', 'HO=[C]')
# ('HO2', 'HO[O]')
# ('HO2CHO', 'HO[O]CHO')
# ('HOCHO', 'HOCHO')
# ('HOCH2O', 'HO[[CH2]]O')
# ('OHA1CH3-O', 'OC1CCCCC1[CH3]-O')
# ('I-C3H7', 'I-C3H7')
# ('N-C3H7CO', 'N-C3H7O=[C]')
# ('N-C3H7CHO', 'N-C3H7CHO')
# ('I-C4H3', 'I-C4H3')
# ('I-C4H5', 'I-C4H5')
# ('I-C4H9', 'I-C4H9')
# ('I-C4H10', 'ICC(C)C')
# ('I-C6H5', 'I-C6H5')
# ('I-C6H7', 'I-C6H7')
# ('N-C3H7', 'N-C3H7')
# ('N-C3H7O', 'N-C3H7O')
# ('N-C3H7O2', 'N-C3H7O[O]')
# ('N-C3H7O2H', 'N-C3H7OO')
# ('N-C4H3', 'N-C4H3')
# ('N-C4H5', 'N-C4H5')
# ('N-C6H7', 'N-C6H7')
# ('O', 'O')
# ('O2', 'O[O]')
# ('O2CHO', 'O[O]CHO')
# ('OCHO', 'OCHO')
# ('OA1CH3-O', 'OC1CCCCC1[CH3]-O')
# ('OH', 'O')
# ('TOLA2', 'TOLC1CCC2CCCCC2C1')
# ('N-C6H5', 'N-C6H5')
# ('C-C6H7', 'C-C6H7')
# ('A1C2H2-R1', 'C1CCCCC1C#C-R1')
# ('A1C2H2-R2', 'C1CCCCC1C#C-R2')
# ('A1C2H-O', 'C1CCCCC1C2H-O')
# ('N2', 'N2')
# ('C3H5O', 'C3H5O')
# ('C2H3CHO', '[CH]=CCHO')
# ('T-C4H9', 'T-C4H9')
# ('CH3CO3', '[CH3]O=[C]3')
# ('CH3CO3H', '[CH3]O=[C]3H')
# ('I-C3H7O', 'I-C3H7O')
# ('I-C3H7O2', 'I-C3H7O[O]')
# ('I-C3H7O2H', 'I-C3H7OO')
# ('I-C4H9O2', 'I-C4H9O[O]')
# ('I-C4H9O2H', 'I-C4H9OO')
# ('T-C4H9O2', 'T-C4H9O[O]')
# ('T-C4H9O2H', 'T-C4H9OO')
# ('I-C4H8', 'I-C4H8')
# ('I-C4H9O', 'I-C4H9O')
# ('I-C3H7CHO', 'I-C3H7CHO')
# ('I-C4H7', 'I-C4H7')
# ('C2H3CO', '[CH]=CO=[C]')
# ('CH3CO2', '[CH3]O=C=O')
# ('T-C4H9O', 'T-C4H9O')
# ('I-C4H7O', 'I-C4H7O')
# ('I-C4H8O2H-I', 'I-C4H8OO-I')
# ('I-C4H8O2H-T', 'I-C4H8OO-T')
# ('CC4H8O', 'CC4H8O')
# ('I-C4H8O', 'I-C4H8O')
# ('C3H5-T', 'C3H5-T')
# ('I-C4H7OH', 'I-C4H7O')
# ('I-C3H5CHO', 'I-C3H5CHO')
# ('CH3COCH2', '[CH3]O=[C][[CH2]]')
# ('I-C4H6OH', 'I-C4H6O')
# ('I-C4H7CO', 'I-C4H7O=[C]')
# ('CH3COCH3', '[CH3]O=[C][CH3]')
# ('I-C3H5CO', 'I-C3H5O=[C]')
# ('T-C3H6OH', 'T-C3H6O')
# ('T-C4H8O2H-I', 'T-C4H8OO-I')
# ('I-C4H8OH', 'I-C4H8O')
# ('IO2C4H8OH', 'IO[O]C4H8O')
# ('A1C2HAC', 'C1CCCCC1C2HAC')
# ('A2', 'C1CCC2CCCCC2C1')
# ('A2-X', 'C1CCC2CCCCC2C1-X')
# ('A2R5', 'C1CCC2CCCCC2C1R5')
# ('A2R5-', 'C1CCC2CCCCC2C1R5-')
# ('A2R5C2H', 'C1CCC2CCCCC2C1R5C2H')
# ('A3R5', 'A3R5')
# ('A3R5-', 'A3R5-')
# ('ANC2HAC', 'ANC2HAC')
# ('A2R5C2H-', 'C1CCC2CCCCC2C1R5C2H-')
# ('A1CH3-M', 'C1CCCCC1[CH3]-M')
# ('OA1CH3-M', 'OC1CCCCC1[CH3]-M')
# ('OHA1CH3-M', 'OC1CCCCC1[CH3]-M')
# ('A1M1OH3-', 'C1CCCCC1M1O3-')
# ('C5H11-1', 'C5H11-1')
# ('C4H7P-1', 'C4H7P-1')
# ('C4H7S-1', 'C4H7S-1')
# ('FC6H6', 'FC6H6')
# ('CYC6H11', 'CYC6H11')
# ('CYC6H10', 'CYC6H10')
# ('CYC6H9', 'CYC6H9')
# ('CYC6H8', 'CYC6H8')
# ('CYC6H7', 'CYC6H7')
# ('CYC6H12', 'CYC6H12')
# ('C4H5O-D1K4R4', 'C4H5O-D1K4R4')
# ('C4H5O-D1K3R4', 'C4H5O-D1K3R4')
# ('C4H6O-D1K3', 'C4H6O-D1K3')
# ('C4H6O-D1K4', 'C4H6O-D1K4')
# ('C5H7-D1D4R3', 'C5H7-D1D4R3')
# ('C5H7O-D1K3R5', 'C5H7O-D1K3R5')
# ('C5H7O-D1K5R5', 'C5H7O-D1K5R5')
# ('C5H7O-D1K4R5', 'C5H7O-D1K4R5')
# ('C5H8-D1D3', 'C5H8-D1D3')
# ('C5H8-D1D4', 'C5H8-D1D4')
# ('C5H8O-D1K5', 'C5H8O-D1K5')
# ('C5H9-D1R3', 'C5H9-D1R3')
# ('C5H9-D1R4', 'C5H9-D1R4')
# ('C5H9-D1R5', 'C5H9-D1R5')
# ('C5H10-1', 'C5H10-1')
# ('C5H10-2', 'C5H10-2')
# ('C5H11-2', 'C5H11-2')
# ('C5H11-3', 'C5H11-3')
# ('C6H9-D1D3R6', 'C6H9-D1D3R6')
# ('C6H9-D1D3R5', 'C6H9-D1D3R5')
# ('C6H9-D1D5R3', 'C6H9-D1D5R3')
# ('C6H10-D1D3', 'C6H10-D1D3')
# ('C6H10-D1D4', 'C6H10-D1D4')
# ('C6H10O-D1E45', 'C6H10O-D1E45')
# ('C6H10O-D1E35', 'C6H10O-D1E35')
# ('C6H10O-D1E34', 'C6H10O-D1E34')
# ('C6H10O-D1E36', 'C6H10O-D1E36')
# ('C6H10O-D1E46', 'C6H10O-D1E46')
# ('C6H10O-D1E56', 'C6H10O-D1E56')
# ('C6H10O3-D1K3HP4', 'C6H10O3-D1K3HP4')
# ('C6H10O3-D1K3HP5', 'C6H10O3-D1K3HP5')
# ('C6H10O3-D1K3HP6', 'C6H10O3-D1K3HP6')
# ('C6H10O3-D1K4HP3', 'C6H10O3-D1K4HP3')
# ('C6H10O3-D1K4HP5', 'C6H10O3-D1K4HP5')
# ('C6H10O3-D1K4HP6', 'C6H10O3-D1K4HP6')
# ('C6H10O3-D1K5HP3', 'C6H10O3-D1K5HP3')
# ('C6H10O3-D1K5HP4', 'C6H10O3-D1K5HP4')
# ('C6H10O3-D1K5HP6', 'C6H10O3-D1K5HP6')
# ('C6H10O3-D1K6HP3', 'C6H10O3-D1K6HP3')
# ('C6H10O3-D1K6HP4', 'C6H10O3-D1K6HP4')
# ('C6H10O3-D1K6HP5', 'C6H10O3-D1K6HP5')
# ('C6H11-D1R3', 'C6H11-D1R3')
# ('C6H11-D1R4', 'C6H11-D1R4')
# ('C6H11-D1R5', 'C6H11-D1R5')
# ('C6H11-D1R6', 'C6H11-D1R6')
# ('C6H11O-D1O3', 'C6H11O-D1O3')
# ('C6H11O-D1O4', 'C6H11O-D1O4')
# ('C6H11O-D1O5', 'C6H11O-D1O5')
# ('C6H11O-D1O6', 'C6H11O-D1O6')
# ('C6H11O2-D1P3', 'C6H11O[O]-D1P3')
# ('C6H11O2-D1P4', 'C6H11O[O]-D1P4')
# ('C6H11O2-D1P5', 'C6H11O[O]-D1P5')
# ('C6H11O2-D1P6', 'C6H11O[O]-D1P6')
# ('C6H11O2-D1HP3R4', 'C6H11O[O]-D1HP3R4')
# ('C6H11O2-D1HP3R5', 'C6H11O[O]-D1HP3R5')
# ('C6H11O2-D1HP3R6', 'C6H11O[O]-D1HP3R6')
# ('C6H11O2-D1HP4R3', 'C6H11O[O]-D1HP4R3')
# ('C6H11O2-D1HP4R5', 'C6H11O[O]-D1HP4R5')
# ('C6H11O2-D1HP4R6', 'C6H11O[O]-D1HP4R6')
# ('C6H11O2-D1HP5R3', 'C6H11O[O]-D1HP5R3')
# ('C6H11O2-D1HP5R4', 'C6H11O[O]-D1HP5R4')
# ('C6H11O2-D1HP5R6', 'C6H11O[O]-D1HP5R6')
# ('C6H11O2-D1HP6R3', 'C6H11O[O]-D1HP6R3')
# ('C6H11O2-D1HP6R4', 'C6H11O[O]-D1HP6R4')
# ('C6H11O2-D1HP6R5', 'C6H11O[O]-D1HP6R5')
# ('C6H11O2H-D1HP3', 'C6H11OO-D1HP3')
# ('C6H11O2H-D1HP4', 'C6H11OO-D1HP4')
# ('C6H11O2H-D1HP5', 'C6H11OO-D1HP5')
# ('C6H11O2H-D1HP6', 'C6H11OO-D1HP6')
# ('C6H11O4-D1HP3P4', 'C6H11O4-D1HP3P4')
# ('C6H11O4-D1HP3P5', 'C6H11O4-D1HP3P5')
# ('C6H11O4-D1HP3P6', 'C6H11O4-D1HP3P6')
# ('C6H11O4-D1HP4P3', 'C6H11O4-D1HP4P3')
# ('C6H11O4-D1HP4P5', 'C6H11O4-D1HP4P5')
# ('C6H11O4-D1HP4P6', 'C6H11O4-D1HP4P6')
# ('C6H11O4-D1HP5P3', 'C6H11O4-D1HP5P3')
# ('C6H11O4-D1HP5P4', 'C6H11O4-D1HP5P4')
# ('C6H11O4-D1HP5P6', 'C6H11O4-D1HP5P6')
# ('C6H11O4-D1HP6P3', 'C6H11O4-D1HP6P3')
# ('C6H11O4-D1HP6P4', 'C6H11O4-D1HP6P4')
# ('C6H11O4-D1HP6P5', 'C6H11O4-D1HP6P5')
# ('C6H12-d1', 'C6H12-d1')

# %%
import re
from rdkit import Chem

# %%
inputfile ="""
! Radicals from the base
R1H   !   .h
R2OH   !   .oh
R3OOH   !   .o/oh
R4CH3   !   .ch3
R5CHO   !   .ch//o
R6CH2OH   !   .ch2/oh
R7CH3O   !   .o/ch3
R8CH3OO   !   .o/o/ch3
R9C2HT   !   .c///ch
R10C2H3V   !   .ch//ch2
R11C2H5   !   .ch2/ch3
R12CHCOV   !   .ch//c//o
R13CH2CHO   !   .ch2/ch//o
R14CH3CO   !   .c(//o)/ch3
R15C2H5O   !   .o/ch2/ch3
R16C2H4OOH   !   .ch2/ch2/o/oh
R17C2H5OO   !   .o/o/ch2/ch3
R18CH3COOO   !   .o/o/c(//o)/ch3
R19C3H7   !   .ch2/ch2/ch3
R20C4H9   !   .ch2/ch2/ch2/ch3
R21CH3OCO   !   .c(//o)/o/ch3
R22CO2H   !   .c(//o)/oh
R23C2H3O2B   !   .ch2/c(//o)/oh
R24C2H4OH   !   .ch2/ch2/oh
R25C2H4OH   !   .ch(/oh)/ch3
! Free radicals :
R26C5H11   !   .ch(/ch2/ch3)2
R27C5H11   !   .ch2/ch2/ch2/ch2/ch3
R28C5H11   !   .ch(/ch3)/ch2/ch2/ch3
R29C6H11OK   !   .c(//o)/ch2/ch2/ch2/ch2/ch3
R30C6H11OA   !   .ch2/ch2/ch2/ch2/ch2/ch//o
R31C6H11OA   !   .ch(/ch3)/ch2/ch2/ch2/ch//o
R32C6H11OA   !   .ch(/ch2/ch3)/ch2/ch2/ch//o
R33C6H11OA   !   .ch(/ch2/ch//o)/ch2/ch2/ch3
R34C6H11OA   !   .ch(/ch//o)/ch2/ch2/ch2/ch3
R35C6H11O2K   !   .o/c(//o)/ch2/ch2/ch2/ch2/ch3
R36C6H11O2B   !   .ch2/ch2/ch2/ch2/ch2/c(//o)/oh
R37C6H11O2B   !   .ch(/ch3)/ch2/ch2/ch2/c(//o)/oh
R38C6H11O2B   !   .ch(/ch2/ch3)/ch2/ch2/c(//o)/oh
R39C6H11O2B   !   .ch(/ch2/c(//o)/oh)/ch2/ch2/ch3
R40C6H11O2B   !   .ch(/c(//o)/oh)/ch2/ch2/ch2/ch3
R41C3H7O2U   !   .o/o/ch2/ch2/ch3
R42C4H9O2U   !   .o/o/ch2/ch2/ch2/ch3
R43C5H11O2U   !   .o/o/ch(/ch2/ch3)2
R44C5H11O2U   !   .o/o/ch2/ch2/ch2/ch2/ch3
R45C5H11O2U   !   .o/o/ch(/ch3)/ch2/ch2/ch3
R46C6H11O3AU   !   .o/o/ch2/ch2/ch2/ch2/ch2/ch//o
R47C4H7OA   !   .ch2/ch2/ch2/ch//o
R48C6H11O3AU   !   .o/o/ch(/ch3)/ch2/ch2/ch2/ch//o
R49C3H5OA   !   .ch2/ch2/ch//o
R50C6H11O3AU   !   .o/o/ch(/ch2/ch3)/ch2/ch2/ch//o
R51C6H11O3AU   !   .o/o/ch(/ch2/ch//o)/ch2/ch2/ch3
R52C6H11O3AU   !   .o/o/ch(/ch//o)/ch2/ch2/ch2/ch3
R53C6H11O4UB   !   .o/o/ch2/ch2/ch2/ch2/ch2/c(//o)/oh
R54C4H7O2B   !   .ch2/ch2/ch2/c(//o)/oh
R55C6H11O4UB   !   .o/o/ch(/ch3)/ch2/ch2/ch2/c(//o)/oh
R56C3H5O2B   !   .ch2/ch2/c(//o)/oh
R57C6H11O4UB   !   .o/o/ch(/ch2/ch3)/ch2/ch2/c(//o)/oh
R58C6H11O4UB   !   .o/o/ch(/ch2/c(//o)/oh)/ch2/ch2/ch3
R59C6H11O4UB   !   .o/o/ch(/c(//o)/oh)/ch2/ch2/ch2/ch3
R60C3H7O2P   !   .ch(/ch3)/ch2/o/oh
R61C3H7O2P   !   .ch2/ch2/ch2/o/oh
R62C4H9O2P   !   .ch(/ch2/o/oh)/ch2/ch3
R63C4H9O2P   !   .ch(/ch3)/ch2/ch2/o/oh
R64C4H9O2P   !   .ch2/ch2/ch2/ch2/o/oh
R65C5H11O2P   !   .ch(/ch3)/ch(/o/oh)/ch2/ch3
R66C5H11O2P   !   .ch2/ch2/ch(/o/oh)/ch2/ch3
R67C5H11O2P   !   .ch(/ch2/o/oh)/ch2/ch2/ch3
R68C5H11O2P   !   .ch(/ch2/ch3)/ch2/ch2/o/oh
R69C5H11O2P   !   .ch(/ch3)/ch2/ch2/ch2/o/oh
R70C5H11O2P   !   .ch2/ch2/ch2/ch2/ch2/o/oh
R71C5H11O2P   !   .ch2/ch(/o/oh)/ch2/ch2/ch3
R72C5H11O2P   !   .ch(/ch2/ch3)/ch(/o/oh)/ch3
R73C5H11O2P   !   .ch(/ch3)/ch2/ch(/o/oh)/ch3
R74C5H11O2P   !   .ch2/ch2/ch2/ch(/o/oh)/ch3
R75C6H11O3AP   !   .ch(/ch2/o/oh)/ch2/ch2/ch2/ch//o
R76C6H11O3AP   !   .ch(/ch2/ch2/o/oh)/ch2/ch2/ch//o
R77C6H11O3AP   !   .ch(/ch2/ch//o)/ch2/ch2/ch2/o/oh
R78C6H11O3AP   !   .ch(/ch//o)/ch2/ch2/ch2/ch2/o/oh
R79C4H7O3AU   !   .o/o/ch2/ch2/ch2/ch//o
R80C4H7OK   !   .c(//o)/ch2/ch2/ch3
R81C6H11O3AP   !   .ch2/ch(/o/oh)/ch2/ch2/ch2/ch//o
R82C6H11O3AP   !   .ch(/ch(/o/oh)/ch3)/ch2/ch2/ch//o
R83C6H11O3AP   !   .ch(/ch2/ch//o)/ch2/ch(/o/oh)/ch3
R84C6H11O3AP   !   .ch(/ch//o)/ch2/ch2/ch(/o/oh)/ch3
R85C6H11O3KP   !   .c(//o)/ch2/ch2/ch2/ch(/o/oh)/ch3
R86C3H5O3AU   !   .o/o/ch2/ch2/ch//o
R87C6H11O3AP   !   .ch(/ch3)/ch(/o/oh)/ch2/ch2/ch//o
R88C6H11O3AP   !   .ch2/ch2/ch(/o/oh)/ch2/ch2/ch//o
R89C6H11O3AP   !   .ch(/ch2/ch//o)/ch(/o/oh)/ch2/ch3
R90C6H11O3AP   !   .ch(/ch//o)/ch2/ch(/o/oh)/ch2/ch3
R91C6H11O3KP   !   .c(//o)/ch2/ch2/ch(/o/oh)/ch2/ch3
R92C6H11O3AP   !   .ch(/ch//o)/ch(/o/oh)/ch2/ch2/ch3
R93C6H11O3KP   !   .c(//o)/ch2/ch(/o/oh)/ch2/ch2/ch3
R94C6H11O3AP   !   .ch(/ch2/ch3)/ch(/o/oh)/ch2/ch//o
R95C6H11O3AP   !   .ch(/ch3)/ch2/ch(/o/oh)/ch2/ch//o
R96C6H11O3AP   !   .ch2/ch2/ch2/ch(/o/oh)/ch2/ch//o
R97C6H11O3KP   !   .c(//o)/ch(/o/oh)/ch2/ch2/ch2/ch3
R98C6H11O3AP   !   .ch(/ch(/o/oh)/ch//o)/ch2/ch2/ch3
R99C6H11O3AP   !   .ch(/ch2/ch3)/ch2/ch(/o/oh)/ch//o
R100C6H11O3AP   !   .ch(/ch3)/ch2/ch2/ch(/o/oh)/ch//o
R101C6H11O3AP   !   .ch2/ch2/ch2/ch2/ch(/o/oh)/ch//o
R102C6H11O4PB   !   .ch(/ch2/o/oh)/ch2/ch2/ch2/c(//o)/oh
R103C6H11O4PB   !   .ch(/ch2/ch2/o/oh)/ch2/ch2/c(//o)/oh
R104C6H11O4PB   !   .ch(/ch2/c(//o)/oh)/ch2/ch2/ch2/o/oh
R105C6H11O4PB   !   .ch(/c(//o)/oh)/ch2/ch2/ch2/ch2/o/oh
R106C4H7O4UB   !   .o/o/ch2/ch2/ch2/c(//o)/oh
R107C6H11O4PB   !   .ch2/ch(/o/oh)/ch2/ch2/ch2/c(//o)/oh
R108C6H11O4PB   !   .ch(/ch(/o/oh)/ch3)/ch2/ch2/c(//o)/oh
R109C6H11O4PB   !   .ch(/ch2/c(//o)/oh)/ch2/ch(/o/oh)/ch3
R110C6H11O4PB   !   .ch(/c(//o)/oh)/ch2/ch2/ch(/o/oh)/ch3
R111C3H5O4UB   !   .o/o/ch2/ch2/c(//o)/oh
R112C6H11O4PB   !   .ch(/ch3)/ch(/o/oh)/ch2/ch2/c(//o)/oh
R113C6H11O4PB   !   .ch2/ch2/ch(/o/oh)/ch2/ch2/c(//o)/oh
R114C6H11O4PB   !   .ch(/ch2/c(//o)/oh)/ch(/o/oh)/ch2/ch3
R115C6H11O4PB   !   .ch(/c(//o)/oh)/ch2/ch(/o/oh)/ch2/ch3
R116C6H11O4PB   !   .ch(/c(//o)/oh)/ch(/o/oh)/ch2/ch2/ch3
R117C6H11O4PB   !   .ch(/ch2/ch3)/ch(/o/oh)/ch2/c(//o)/oh
R118C6H11O4PB   !   .ch(/ch3)/ch2/ch(/o/oh)/ch2/c(//o)/oh
R119C6H11O4PB   !   .ch2/ch2/ch2/ch(/o/oh)/ch2/c(//o)/oh
R120C6H11O4PB   !   .ch(/ch(/o/oh)/c(//o)/oh)/ch2/ch2/ch3
R121C6H11O4PB   !   .ch(/ch2/ch3)/ch2/ch(/o/oh)/c(//o)/oh
R122C6H11O4PB   !   .ch(/ch3)/ch2/ch2/ch(/o/oh)/c(//o)/oh
R123C6H11O4PB   !   .ch2/ch2/ch2/ch2/ch(/o/oh)/c(//o)/oh
R124C3H7O4UP   !   .o/o/ch(/ch3)/ch2/o/oh
R125C3H7O4UP   !   .o/o/ch2/ch2/ch2/o/oh
R126C4H9O4UP   !   .o/o/ch(/ch2/o/oh)/ch2/ch3
R127C4H9O4UP   !   .o/o/ch(/ch3)/ch2/ch2/o/oh
R128C4H9O4UP   !   .o/o/ch2/ch2/ch2/ch2/o/oh
R129C5H11O4UP   !   .o/o/ch(/ch3)/ch(/o/oh)/ch2/ch3
R130C5H11O4UP   !   .o/o/ch2/ch2/ch(/o/oh)/ch2/ch3
R131C3H7O2P   !   .ch(/o/oh)/ch2/ch3
R132C5H11O4UP   !   .o/o/ch(/ch2/o/oh)/ch2/ch2/ch3
R133C5H11O4UP   !   .o/o/ch(/ch2/ch3)/ch2/ch2/o/oh
R134C5H11O4UP   !   .o/o/ch(/ch3)/ch2/ch2/ch2/o/oh
R135C5H11O4UP   !   .o/o/ch2/ch2/ch2/ch2/ch2/o/oh
R136C5H11O4UP   !   .o/o/ch2/ch(/o/oh)/ch2/ch2/ch3
R137C5H11O4UP   !   .o/o/ch(/ch2/ch3)/ch(/o/oh)/ch3
R138C5H11O4UP   !   .o/o/ch(/ch3)/ch2/ch(/o/oh)/ch3
R139C5H11O4UP   !   .o/o/ch2/ch2/ch2/ch(/o/oh)/ch3
R140C3H7O2P   !   .ch2/ch(/o/oh)/ch3
R141C6H11O5AUP   !   .o/o/ch(/ch2/o/oh)/ch2/ch2/ch2/ch//o
R142C6H11O3KP   !   .c(//o)/ch2/ch2/ch2/ch2/ch2/o/oh
R143C6H11O5AUP   !   .o/o/ch(/ch2/ch2/o/oh)/ch2/ch2/ch//o
R144C6H11O5AUP   !   .o/o/ch(/ch2/ch//o)/ch2/ch2/ch2/o/oh
R145C6H11O5AUP   !   .o/o/ch(/ch//o)/ch2/ch2/ch2/ch2/o/oh
R146C4H7O3AP   !   .ch(/ch2/o/oh)/ch2/ch//o
R147C4H7O3AP   !   .ch(/ch//o)/ch2/ch2/o/oh
R148C4H7O3KP   !   .c(//o)/ch2/ch2/ch2/o/oh
R149C6H11O5AUP   !   .o/o/ch2/ch(/o/oh)/ch2/ch2/ch2/ch//o
R150C6H11O5AUP   !   .o/o/ch(/ch(/o/oh)/ch3)/ch2/ch2/ch//o
R151C6H11O5AUP   !   .o/o/ch(/ch2/ch//o)/ch2/ch(/o/oh)/ch3
R152C6H11O5AUP   !   .o/o/ch(/ch//o)/ch2/ch2/ch(/o/oh)/ch3
R153C3H5O3AP   !   .ch(/ch//o)/ch2/o/oh
R154C3H5O3KP   !   .c(//o)/ch2/ch2/o/oh
R155C6H11O5AUP   !   .o/o/ch(/ch3)/ch(/o/oh)/ch2/ch2/ch//o
R156C6H11O5AUP   !   .o/o/ch2/ch2/ch(/o/oh)/ch2/ch2/ch//o
R157C4H7O3AP   !   .ch(/o/oh)/ch2/ch2/ch//o
R158C6H11O5AUP   !   .o/o/ch(/ch2/ch//o)/ch(/o/oh)/ch2/ch3
R159C6H11O5AUP   !   .o/o/ch(/ch//o)/ch2/ch(/o/oh)/ch2/ch3
R160C6H11O5AUP   !   .o/o/ch(/ch//o)/ch(/o/oh)/ch2/ch2/ch3
R161C6H11O5AUP   !   .o/o/ch(/ch2/ch3)/ch(/o/oh)/ch2/ch//o
R162C6H11O5AUP   !   .o/o/ch(/ch3)/ch2/ch(/o/oh)/ch2/ch//o
R163C3H5O3AP   !   .ch(/o/oh)/ch2/ch//o
R164C6H11O5AUP   !   .o/o/ch2/ch2/ch2/ch(/o/oh)/ch2/ch//o
R165C4H7O3AP   !   .ch2/ch(/o/oh)/ch2/ch//o
R166C5H11O2P   !   .ch(/o/oh)/ch2/ch2/ch2/ch3
R167C6H11O5AUP   !   .o/o/ch(/ch(/o/oh)/ch//o)/ch2/ch2/ch3
R168C6H11O5AUP   !   .o/o/ch(/ch2/ch3)/ch2/ch(/o/oh)/ch//o
R169C6H11O5AUP   !   .o/o/ch(/ch3)/ch2/ch2/ch(/o/oh)/ch//o
R170C3H5O3AP   !   .ch2/ch(/o/oh)/ch//o
R171C6H11O5AUP   !   .o/o/ch2/ch2/ch2/ch2/ch(/o/oh)/ch//o
R172C4H7O3AP   !   .ch2/ch2/ch(/o/oh)/ch//o
R173C6H11O6UPB   !   .o/o/ch(/ch2/o/oh)/ch2/ch2/ch2/c(//o)/oh
R174C6H11O6UPB   !   .o/o/ch(/ch2/ch2/o/oh)/ch2/ch2/c(//o)/oh
R175C6H11O6UPB   !   .o/o/ch(/ch2/c(//o)/oh)/ch2/ch2/ch2/o/oh
R176C6H11O6UPB   !   .o/o/ch(/c(//o)/oh)/ch2/ch2/ch2/ch2/o/oh
R177C4H7O4PB   !   .ch(/ch2/o/oh)/ch2/c(//o)/oh
R178C4H7O4PB   !   .ch(/c(//o)/oh)/ch2/ch2/o/oh
R179C6H11O6UPB   !   .o/o/ch2/ch(/o/oh)/ch2/ch2/ch2/c(//o)/oh
R180C6H11O6UPB   !   .o/o/ch(/ch(/o/oh)/ch3)/ch2/ch2/c(//o)/oh
R181C6H11O6UPB   !   .o/o/ch(/ch2/c(//o)/oh)/ch2/ch(/o/oh)/ch3
R182C6H11O6UPB   !   .o/o/ch(/c(//o)/oh)/ch2/ch2/ch(/o/oh)/ch3
R183C3H5O4PB   !   .ch(/c(//o)/oh)/ch2/o/oh
R184C6H11O6UPB   !   .o/o/ch(/ch3)/ch(/o/oh)/ch2/ch2/c(//o)/oh
R185C6H11O6UPB   !   .o/o/ch2/ch2/ch(/o/oh)/ch2/ch2/c(//o)/oh
R186C4H7O4PB   !   .ch(/o/oh)/ch2/ch2/c(//o)/oh
R187C6H11O6UPB   !   .o/o/ch(/ch2/c(//o)/oh)/ch(/o/oh)/ch2/ch3
R188C6H11O6UPB   !   .o/o/ch(/c(//o)/oh)/ch2/ch(/o/oh)/ch2/ch3
R189C6H11O6UPB   !   .o/o/ch(/c(//o)/oh)/ch(/o/oh)/ch2/ch2/ch3
R190C6H11O6UPB   !   .o/o/ch(/ch2/ch3)/ch(/o/oh)/ch2/c(//o)/oh
R191C6H11O6UPB   !   .o/o/ch(/ch3)/ch2/ch(/o/oh)/ch2/c(//o)/oh
R192C3H5O4PB   !   .ch(/o/oh)/ch2/c(//o)/oh
R193C6H11O6UPB   !   .o/o/ch2/ch2/ch2/ch(/o/oh)/ch2/c(//o)/oh
R194C4H7O4PB   !   .ch2/ch(/o/oh)/ch2/c(//o)/oh
R195C6H11O6UPB   !   .o/o/ch(/ch(/o/oh)/c(//o)/oh)/ch2/ch2/ch3
R196C6H11O6UPB   !   .o/o/ch(/ch2/ch3)/ch2/ch(/o/oh)/c(//o)/oh
R197C6H11O6UPB   !   .o/o/ch(/ch3)/ch2/ch2/ch(/o/oh)/c(//o)/oh
R198C3H5O4PB   !   .ch2/ch(/o/oh)/c(//o)/oh
R199C6H11O6UPB   !   .o/o/ch2/ch2/ch2/ch2/ch(/o/oh)/c(//o)/oh
R200C4H7O4PB   !   .ch2/ch2/ch(/o/oh)/c(//o)/oh
R201C3H7O4UP   !   .o/o/ch(/o/oh)/ch2/ch3
R202C3H7O4UP   !   .o/o/ch2/ch(/o/oh)/ch3
R203C3H7O2U   !   .o/o/ch(/ch3)2
R204C4H7O5AUP   !   .o/o/ch(/ch2/o/oh)/ch2/ch//o
R205C4H7O5AUP   !   .o/o/ch(/ch//o)/ch2/ch2/o/oh
R206C3H5O5AUP   !   .o/o/ch(/ch//o)/ch2/o/oh
R207C4H7O5AUP   !   .o/o/ch(/o/oh)/ch2/ch2/ch//o
R208C3H5O5AUP   !   .o/o/ch(/o/oh)/ch2/ch//o
R209C4H7O5AUP   !   .o/o/ch2/ch(/o/oh)/ch2/ch//o
R210C4H7O3AU   !   .o/o/ch(/ch3)/ch2/ch//o
R211C4H7O3KP   !   .c(//o)/ch2/ch(/o/oh)/ch3
R212C5H11O4UP   !   .o/o/ch(/o/oh)/ch2/ch2/ch2/ch3
R213C3H5O5AUP   !   .o/o/ch2/ch(/o/oh)/ch//o
R214C3H5O3AU   !   .o/o/ch(/ch3)/ch//o
R215C4H7O5AUP   !   .o/o/ch2/ch2/ch(/o/oh)/ch//o
R216C4H7O3AU   !   .o/o/ch(/ch//o)/ch2/ch3
R217C4H7O3KP   !   .c(//o)/ch(/o/oh)/ch2/ch3
R218C4H7O6UPB   !   .o/o/ch(/ch2/o/oh)/ch2/c(//o)/oh
R219C4H7O6UPB   !   .o/o/ch(/c(//o)/oh)/ch2/ch2/o/oh
R220C3H5O6UPB   !   .o/o/ch(/c(//o)/oh)/ch2/o/oh
R221C4H7O6UPB   !   .o/o/ch(/o/oh)/ch2/ch2/c(//o)/oh
R222C3H5O6UPB   !   .o/o/ch(/o/oh)/ch2/c(//o)/oh
R223C4H7O6UPB   !   .o/o/ch2/ch(/o/oh)/ch2/c(//o)/oh
R224C4H7O4UB   !   .o/o/ch(/ch3)/ch2/c(//o)/oh
R225C3H5O6UPB   !   .o/o/ch2/ch(/o/oh)/c(//o)/oh
R226C3H5O4UB   !   .o/o/ch(/ch3)/c(//o)/oh
R227C4H7O6UPB   !   .o/o/ch2/ch2/ch(/o/oh)/c(//o)/oh
R228C4H7O4UB   !   .o/o/ch(/c(//o)/oh)/ch2/ch3
R229C3H7   !   .ch(/ch3)2
R230C4H7O3AP   !   .ch(/ch//o)/ch(/o/oh)/ch3
R231C4H7OA   !   .ch(/ch3)/ch2/ch//o
R232C3H5O3KP   !   .c(//o)/ch(/o/oh)/ch3
R233C3H5OA   !   .ch(/ch3)/ch//o
R234C4H7O3AP   !   .ch(/ch3)/ch(/o/oh)/ch//o
R235C4H7OA   !   .ch(/ch//o)/ch2/ch3
R236C4H7O4PB   !   .ch(/c(//o)/oh)/ch(/o/oh)/ch3
R237C4H7O2B   !   .ch(/ch3)/ch2/c(//o)/oh
R238C3H5O2B   !   .ch(/ch3)/c(//o)/oh
R239C4H7O4PB   !   .ch(/ch3)/ch(/o/oh)/c(//o)/oh
R240C4H7O2B   !   .ch(/c(//o)/oh)/ch2/ch3
R241C4H7O5AUP   !   .o/o/ch(/ch//o)/ch(/o/oh)/ch3
R242C4H7O5AUP   !   .o/o/ch(/ch3)/ch(/o/oh)/ch//o
R243C4H7O6UPB   !   .o/o/ch(/c(//o)/oh)/ch(/o/oh)/ch3
R244C4H7O6UPB   !   .o/o/ch(/ch3)/ch(/o/oh)/c(//o)/oh
R245C5H9OA   !   .ch2/ch2/ch2/ch2/ch//o
R246C5H9O2B   !   .ch2/ch2/ch2/ch2/c(//o)/oh


# !Added species
R290C6H11O3AU !ch3/ch2/ch2/ch2/ch2/c(/o/o(.))//o
R291C6H11O3AP !ch3/ch2/ch2/ch(.)/ch2/c(/o/oh)//o
R292C6H11O3AP !ch3/ch2/ch(.)/ch2/ch2/c(/o/oh)//o
R293C6H11O3AP !ch3/ch(.)/ch2/ch2/ch2/c(/o/oh)//o
R300C6H11O5APU !ch3/ch2/ch2/ch(/o/o(.))/ch2/c(/o/oh)//o
R301C6H11O5APU !ch3/ch2/ch(/o/o(.))/ch2/ch2/c(/o/oh)//o
R302C6H11O5APU !ch3/ch(/o/o(.))/ch2/ch2/ch2/c(/o/oh)//o
R305C6H11O5APP !ch3/ch(.)/ch2/ch(/o/oh)/ch2/c(/o/oh)//o
R306C6H11O5APP
R307C6H11O5APP
R310C6H11O7APPU !ch3/ch(/o/o(.))/ch2/ch(/o/oh)/ch2/c(/o/oh)//o
R311C6H11O7APPU
R312C6H11O7APPU
C6H8OK(OOH)2O !ch3/ch(/o/oh)/ch2/c(//o)/ch2/c(/o/oh)//o
C6H11OKOOH !ch3/ch2/ch2/ch2/ch2/c(/o/oh)//o
gcaprolac ! ch2(#1)/ch(/ch2/ch3)/o/c(//o)/ch2/1
dcaprolac ! ch2(#1)/ch(/ch3)/o/c(//o)/ch2/ch2/1
C6H12OOOHP !ch3/ch2/ch2/ch2/ch2/ch(/o/oh)/o(.)
HCOOOH !ch(//o)/o/oh
C6H11OKOH !ch3/ch2/ch2/ch2/ch2/ch(/oh)/o(.)
C6H11OKO ! ch3/ch2/ch2/ch2/ch2/c(//o)/o(.)
        """

# %%
structures = {}
for line in inputfile.splitlines():
    if '!' not in line: continue
    if not line.split('!')[0].strip():
        continue
    name, structure = (s.strip() for s in line.split('!'))
    structures[name]=structure

# %%
raw_smiles = {}
for name, structure in structures.iteritems():
    s = structure
    s = re.sub('/?ch3','[CH3]',s)
    s = re.sub('/?ch2','[CH2]',s)
    s = re.sub('/?ch','[CH]',s)
    s = re.sub('/?c','[C]',s)
    s = s.replace('//o','=O')
    s = re.sub('/?oh','[OH]',s)
    s = re.sub('/?o','[O]',s)
    s = re.sub('\(?\.\)?','',s)
    s = re.sub('^h$','[H]',s)
    s = s.replace('//','#') # if you still have a // by now it started as a ///
    if '(#1)' in s:
        assert '/1' in s
        s = s.replace('(#1)','1').replace('/1','1')

    def expander(match):
        """
        For use in regular expressions substitution.
        Accepts a Match object with two groups, first is the bracket to repeat,
        second is the number of times to repeat it.
        """
        number = int(match.group(2)) # how many times to repeat
        result  = match.group(1) * number
        print "Expanding {} to {} in string {}".format(match.string[match.start():match.end()], result, match.string)
        return result
    
    s = re.sub('(\([^)]+\))(\d+)', expander, s)
    
    raw_smiles[name] = s
# Out:
# Expanding ([CH3])2 to ([CH3])([CH3]) in string [CH]([CH3])2
# Expanding ([CH2][CH3])2 to ([CH2][CH3])([CH2][CH3]) in string [CH]([CH2][CH3])2
# Expanding ([CH2][CH3])2 to ([CH2][CH3])([CH2][CH3]) in string [O][O][CH]([CH2][CH3])2
# Expanding ([CH3])2 to ([CH3])([CH3]) in string [O][O][CH]([CH3])2

# %%
smiless = {}
for name, smiles in raw_smiles.iteritems():
    try:
        molecule = Chem.MolFromSmiles(smiles) # turn it into an rdkit molecule
        smiles = Chem.MolToSmiles(molecule,True) # turn it back into a (canonical) smiles
    except:
        print "couldn't convert ", name, structures[name], smiles
    smiless[name] = smiles
    #print name, smiles

# %%
for name in sorted(smiless.keys()):
    smiles = smiless[name] 
    print "{}\t{}\t! Confirmed by translating name automatically".format(name,smiles)
# Out:
# C6H11OKO	CCCCCC([O])=O	! Confirmed by translating name automatically
# C6H11OKOH	CCCCCC([O])O	! Confirmed by translating name automatically
# C6H11OKOOH	CCCCCC(=O)OO	! Confirmed by translating name automatically
# C6H12OOOHP	CCCCCC([O])OO	! Confirmed by translating name automatically
# C6H8OK(OOH)2O	CC(CC(=O)CC(=O)OO)OO	! Confirmed by translating name automatically
# HCOOOH	O=COO	! Confirmed by translating name automatically
# R100C6H11O3AP	C[CH]CCC(C=O)OO	! Confirmed by translating name automatically
# R101C6H11O3AP	[CH2]CCCC(C=O)OO	! Confirmed by translating name automatically
# R102C6H11O4PB	O=C(O)CCC[CH]COO	! Confirmed by translating name automatically
# R103C6H11O4PB	O=C(O)CC[CH]CCOO	! Confirmed by translating name automatically
# R104C6H11O4PB	O=C(O)C[CH]CCCOO	! Confirmed by translating name automatically
# R105C6H11O4PB	O=C(O)[CH]CCCCOO	! Confirmed by translating name automatically
# R106C4H7O4UB	[O]OCCCC(=O)O	! Confirmed by translating name automatically
# R107C6H11O4PB	[CH2]C(CCCC(=O)O)OO	! Confirmed by translating name automatically
# R108C6H11O4PB	CC([CH]CCC(=O)O)OO	! Confirmed by translating name automatically
# R109C6H11O4PB	CC(C[CH]CC(=O)O)OO	! Confirmed by translating name automatically
# R10C2H3V	[CH][CH2]	! Confirmed by translating name automatically
# R110C6H11O4PB	CC(CC[CH]C(=O)O)OO	! Confirmed by translating name automatically
# R111C3H5O4UB	[O]OCCC(=O)O	! Confirmed by translating name automatically
# R112C6H11O4PB	C[CH]C(CCC(=O)O)OO	! Confirmed by translating name automatically
# R113C6H11O4PB	[CH2]CC(CCC(=O)O)OO	! Confirmed by translating name automatically
# R114C6H11O4PB	CCC([CH]CC(=O)O)OO	! Confirmed by translating name automatically
# R115C6H11O4PB	CCC(C[CH]C(=O)O)OO	! Confirmed by translating name automatically
# R116C6H11O4PB	CCCC([CH]C(=O)O)OO	! Confirmed by translating name automatically
# R117C6H11O4PB	CC[CH]C(CC(=O)O)OO	! Confirmed by translating name automatically
# R118C6H11O4PB	C[CH]CC(CC(=O)O)OO	! Confirmed by translating name automatically
# R119C6H11O4PB	[CH2]CCC(CC(=O)O)OO	! Confirmed by translating name automatically
# R11C2H5	[CH2]C	! Confirmed by translating name automatically
# R120C6H11O4PB	CCC[CH]C(OO)C(=O)O	! Confirmed by translating name automatically
# R121C6H11O4PB	CC[CH]CC(OO)C(=O)O	! Confirmed by translating name automatically
# R122C6H11O4PB	C[CH]CCC(OO)C(=O)O	! Confirmed by translating name automatically
# R123C6H11O4PB	[CH2]CCCC(OO)C(=O)O	! Confirmed by translating name automatically
# R124C3H7O4UP	CC(COO)O[O]	! Confirmed by translating name automatically
# R125C3H7O4UP	[O]OCCCOO	! Confirmed by translating name automatically
# R126C4H9O4UP	CCC(COO)O[O]	! Confirmed by translating name automatically
# R127C4H9O4UP	CC(CCOO)O[O]	! Confirmed by translating name automatically
# R128C4H9O4UP	[O]OCCCCOO	! Confirmed by translating name automatically
# R129C5H11O4UP	CCC(OO)C(C)O[O]	! Confirmed by translating name automatically
# R12CHCOV	[CH][C]=O	! Confirmed by translating name automatically
# R130C5H11O4UP	CCC(CCO[O])OO	! Confirmed by translating name automatically
# R131C3H7O2P	CC[CH]OO	! Confirmed by translating name automatically
# R132C5H11O4UP	CCCC(COO)O[O]	! Confirmed by translating name automatically
# R133C5H11O4UP	CCC(CCOO)O[O]	! Confirmed by translating name automatically
# R134C5H11O4UP	CC(CCCOO)O[O]	! Confirmed by translating name automatically
# R135C5H11O4UP	[O]OCCCCCOO	! Confirmed by translating name automatically
# R136C5H11O4UP	CCCC(CO[O])OO	! Confirmed by translating name automatically
# R137C5H11O4UP	CCC(O[O])C(C)OO	! Confirmed by translating name automatically
# R138C5H11O4UP	CC(CC(C)OO)O[O]	! Confirmed by translating name automatically
# R139C5H11O4UP	CC(CCCO[O])OO	! Confirmed by translating name automatically
# R13CH2CHO	[CH2]C=O	! Confirmed by translating name automatically
# R140C3H7O2P	[CH2]C(C)OO	! Confirmed by translating name automatically
# R141C6H11O5AUP	[O]OC(CCCC=O)COO	! Confirmed by translating name automatically
# R142C6H11O3KP	O=[C]CCCCCOO	! Confirmed by translating name automatically
# R143C6H11O5AUP	[O]OC(CCC=O)CCOO	! Confirmed by translating name automatically
# R144C6H11O5AUP	[O]OC(CC=O)CCCOO	! Confirmed by translating name automatically
# R145C6H11O5AUP	[O]OC(C=O)CCCCOO	! Confirmed by translating name automatically
# R146C4H7O3AP	O=CC[CH]COO	! Confirmed by translating name automatically
# R147C4H7O3AP	O=C[CH]CCOO	! Confirmed by translating name automatically
# R148C4H7O3KP	O=[C]CCCOO	! Confirmed by translating name automatically
# R149C6H11O5AUP	[O]OCC(CCCC=O)OO	! Confirmed by translating name automatically
# R14CH3CO	C[C]=O	! Confirmed by translating name automatically
# R150C6H11O5AUP	CC(OO)C(CCC=O)O[O]	! Confirmed by translating name automatically
# R151C6H11O5AUP	CC(CC(CC=O)O[O])OO	! Confirmed by translating name automatically
# R152C6H11O5AUP	CC(CCC(C=O)O[O])OO	! Confirmed by translating name automatically
# R153C3H5O3AP	O=C[CH]COO	! Confirmed by translating name automatically
# R154C3H5O3KP	O=[C]CCOO	! Confirmed by translating name automatically
# R155C6H11O5AUP	CC(O[O])C(CCC=O)OO	! Confirmed by translating name automatically
# R156C6H11O5AUP	[O]OCCC(CCC=O)OO	! Confirmed by translating name automatically
# R157C4H7O3AP	O=CCC[CH]OO	! Confirmed by translating name automatically
# R158C6H11O5AUP	CCC(OO)C(CC=O)O[O]	! Confirmed by translating name automatically
# R159C6H11O5AUP	CCC(CC(C=O)O[O])OO	! Confirmed by translating name automatically
# R15C2H5O	CC[O]	! Confirmed by translating name automatically
# R160C6H11O5AUP	CCCC(OO)C(C=O)O[O]	! Confirmed by translating name automatically
# R161C6H11O5AUP	CCC(O[O])C(CC=O)OO	! Confirmed by translating name automatically
# R162C6H11O5AUP	CC(CC(CC=O)OO)O[O]	! Confirmed by translating name automatically
# R163C3H5O3AP	O=CC[CH]OO	! Confirmed by translating name automatically
# R164C6H11O5AUP	[O]OCCCC(CC=O)OO	! Confirmed by translating name automatically
# R165C4H7O3AP	[CH2]C(CC=O)OO	! Confirmed by translating name automatically
# R166C5H11O2P	CCCC[CH]OO	! Confirmed by translating name automatically
# R167C6H11O5AUP	CCCC(O[O])C(C=O)OO	! Confirmed by translating name automatically
# R168C6H11O5AUP	CCC(CC(C=O)OO)O[O]	! Confirmed by translating name automatically
# R169C6H11O5AUP	CC(CCC(C=O)OO)O[O]	! Confirmed by translating name automatically
# R16C2H4OOH	[CH2]COO	! Confirmed by translating name automatically
# R170C3H5O3AP	[CH2]C(C=O)OO	! Confirmed by translating name automatically
# R171C6H11O5AUP	[O]OCCCCC(C=O)OO	! Confirmed by translating name automatically
# R172C4H7O3AP	[CH2]CC(C=O)OO	! Confirmed by translating name automatically
# R173C6H11O6UPB	[O]OC(CCCC(=O)O)COO	! Confirmed by translating name automatically
# R174C6H11O6UPB	[O]OC(CCOO)CCC(=O)O	! Confirmed by translating name automatically
# R175C6H11O6UPB	[O]OC(CCCOO)CC(=O)O	! Confirmed by translating name automatically
# R176C6H11O6UPB	[O]OC(CCCCOO)C(=O)O	! Confirmed by translating name automatically
# R177C4H7O4PB	O=C(O)C[CH]COO	! Confirmed by translating name automatically
# R178C4H7O4PB	O=C(O)[CH]CCOO	! Confirmed by translating name automatically
# R179C6H11O6UPB	[O]OCC(CCCC(=O)O)OO	! Confirmed by translating name automatically
# R17C2H5OO	CCO[O]	! Confirmed by translating name automatically
# R180C6H11O6UPB	CC(OO)C(CCC(=O)O)O[O]	! Confirmed by translating name automatically
# R181C6H11O6UPB	CC(CC(CC(=O)O)O[O])OO	! Confirmed by translating name automatically
# R182C6H11O6UPB	CC(CCC(O[O])C(=O)O)OO	! Confirmed by translating name automatically
# R183C3H5O4PB	O=C(O)[CH]COO	! Confirmed by translating name automatically
# R184C6H11O6UPB	CC(O[O])C(CCC(=O)O)OO	! Confirmed by translating name automatically
# R185C6H11O6UPB	[O]OCCC(CCC(=O)O)OO	! Confirmed by translating name automatically
# R186C4H7O4PB	O=C(O)CC[CH]OO	! Confirmed by translating name automatically
# R187C6H11O6UPB	CCC(OO)C(CC(=O)O)O[O]	! Confirmed by translating name automatically
# R188C6H11O6UPB	CCC(CC(O[O])C(=O)O)OO	! Confirmed by translating name automatically
# R189C6H11O6UPB	CCCC(OO)C(O[O])C(=O)O	! Confirmed by translating name automatically
# R18CH3COOO	CC(=O)O[O]	! Confirmed by translating name automatically
# R190C6H11O6UPB	CCC(O[O])C(CC(=O)O)OO	! Confirmed by translating name automatically
# R191C6H11O6UPB	CC(CC(CC(=O)O)OO)O[O]	! Confirmed by translating name automatically
# R192C3H5O4PB	O=C(O)C[CH]OO	! Confirmed by translating name automatically
# R193C6H11O6UPB	[O]OCCCC(CC(=O)O)OO	! Confirmed by translating name automatically
# R194C4H7O4PB	[CH2]C(CC(=O)O)OO	! Confirmed by translating name automatically
# R195C6H11O6UPB	CCCC(O[O])C(OO)C(=O)O	! Confirmed by translating name automatically
# R196C6H11O6UPB	CCC(CC(OO)C(=O)O)O[O]	! Confirmed by translating name automatically
# R197C6H11O6UPB	CC(CCC(OO)C(=O)O)O[O]	! Confirmed by translating name automatically
# R198C3H5O4PB	[CH2]C(OO)C(=O)O	! Confirmed by translating name automatically
# R199C6H11O6UPB	[O]OCCCCC(OO)C(=O)O	! Confirmed by translating name automatically
# R19C3H7	[CH2]CC	! Confirmed by translating name automatically
# R1H	[H]	! Confirmed by translating name automatically
# R200C4H7O4PB	[CH2]CC(OO)C(=O)O	! Confirmed by translating name automatically
# R201C3H7O4UP	CCC(O[O])OO	! Confirmed by translating name automatically
# R202C3H7O4UP	CC(CO[O])OO	! Confirmed by translating name automatically
# R203C3H7O2U	CC(C)O[O]	! Confirmed by translating name automatically
# R204C4H7O5AUP	[O]OC(CC=O)COO	! Confirmed by translating name automatically
# R205C4H7O5AUP	[O]OC(C=O)CCOO	! Confirmed by translating name automatically
# R206C3H5O5AUP	[O]OC(C=O)COO	! Confirmed by translating name automatically
# R207C4H7O5AUP	[O]OC(CCC=O)OO	! Confirmed by translating name automatically
# R208C3H5O5AUP	[O]OC(CC=O)OO	! Confirmed by translating name automatically
# R209C4H7O5AUP	[O]OCC(CC=O)OO	! Confirmed by translating name automatically
# R20C4H9	[CH2]CCC	! Confirmed by translating name automatically
# R210C4H7O3AU	CC(CC=O)O[O]	! Confirmed by translating name automatically
# R211C4H7O3KP	CC(C[C]=O)OO	! Confirmed by translating name automatically
# R212C5H11O4UP	CCCCC(O[O])OO	! Confirmed by translating name automatically
# R213C3H5O5AUP	[O]OCC(C=O)OO	! Confirmed by translating name automatically
# R214C3H5O3AU	CC(C=O)O[O]	! Confirmed by translating name automatically
# R215C4H7O5AUP	[O]OCCC(C=O)OO	! Confirmed by translating name automatically
# R216C4H7O3AU	CCC(C=O)O[O]	! Confirmed by translating name automatically
# R217C4H7O3KP	CCC([C]=O)OO	! Confirmed by translating name automatically
# R218C4H7O6UPB	[O]OC(COO)CC(=O)O	! Confirmed by translating name automatically
# R219C4H7O6UPB	[O]OC(CCOO)C(=O)O	! Confirmed by translating name automatically
# R21CH3OCO	CO[C]=O	! Confirmed by translating name automatically
# R220C3H5O6UPB	[O]OC(COO)C(=O)O	! Confirmed by translating name automatically
# R221C4H7O6UPB	[O]OC(CCC(=O)O)OO	! Confirmed by translating name automatically
# R222C3H5O6UPB	[O]OC(CC(=O)O)OO	! Confirmed by translating name automatically
# R223C4H7O6UPB	[O]OCC(CC(=O)O)OO	! Confirmed by translating name automatically
# R224C4H7O4UB	CC(CC(=O)O)O[O]	! Confirmed by translating name automatically
# R225C3H5O6UPB	[O]OCC(OO)C(=O)O	! Confirmed by translating name automatically
# R226C3H5O4UB	CC(O[O])C(=O)O	! Confirmed by translating name automatically
# R227C4H7O6UPB	[O]OCCC(OO)C(=O)O	! Confirmed by translating name automatically
# R228C4H7O4UB	CCC(O[O])C(=O)O	! Confirmed by translating name automatically
# R229C3H7	C[CH]C	! Confirmed by translating name automatically
# R22CO2H	O=[C]O	! Confirmed by translating name automatically
# R230C4H7O3AP	CC([CH]C=O)OO	! Confirmed by translating name automatically
# R231C4H7OA	C[CH]CC=O	! Confirmed by translating name automatically
# R232C3H5O3KP	CC([C]=O)OO	! Confirmed by translating name automatically
# R233C3H5OA	C[CH]C=O	! Confirmed by translating name automatically
# R234C4H7O3AP	C[CH]C(C=O)OO	! Confirmed by translating name automatically
# R235C4H7OA	CC[CH]C=O	! Confirmed by translating name automatically
# R236C4H7O4PB	CC([CH]C(=O)O)OO	! Confirmed by translating name automatically
# R237C4H7O2B	C[CH]CC(=O)O	! Confirmed by translating name automatically
# R238C3H5O2B	C[CH]C(=O)O	! Confirmed by translating name automatically
# R239C4H7O4PB	C[CH]C(OO)C(=O)O	! Confirmed by translating name automatically
# R23C2H3O2B	[CH2]C(=O)O	! Confirmed by translating name automatically
# R240C4H7O2B	CC[CH]C(=O)O	! Confirmed by translating name automatically
# R241C4H7O5AUP	CC(OO)C(C=O)O[O]	! Confirmed by translating name automatically
# R242C4H7O5AUP	CC(O[O])C(C=O)OO	! Confirmed by translating name automatically
# R243C4H7O6UPB	CC(OO)C(O[O])C(=O)O	! Confirmed by translating name automatically
# R244C4H7O6UPB	CC(O[O])C(OO)C(=O)O	! Confirmed by translating name automatically
# R245C5H9OA	[CH2]CCCC=O	! Confirmed by translating name automatically
# R246C5H9O2B	[CH2]CCCC(=O)O	! Confirmed by translating name automatically
# R24C2H4OH	[CH2]CO	! Confirmed by translating name automatically
# R25C2H4OH	C[CH]O	! Confirmed by translating name automatically
# R26C5H11	CC[CH]CC	! Confirmed by translating name automatically
# R27C5H11	[CH2]CCCC	! Confirmed by translating name automatically
# R28C5H11	C[CH]CCC	! Confirmed by translating name automatically
# R290C6H11O3AU	CCCCCC(=O)O[O]	! Confirmed by translating name automatically
# R291C6H11O3AP	CCC[CH]CC(=O)OO	! Confirmed by translating name automatically
# R292C6H11O3AP	CC[CH]CCC(=O)OO	! Confirmed by translating name automatically
# R293C6H11O3AP	C[CH]CCCC(=O)OO	! Confirmed by translating name automatically
# R29C6H11OK	CCCCC[C]=O	! Confirmed by translating name automatically
# R2OH	[OH]	! Confirmed by translating name automatically
# R300C6H11O5APU	CCCC(CC(=O)OO)O[O]	! Confirmed by translating name automatically
# R301C6H11O5APU	CCC(CCC(=O)OO)O[O]	! Confirmed by translating name automatically
# R302C6H11O5APU	CC(CCCC(=O)OO)O[O]	! Confirmed by translating name automatically
# R305C6H11O5APP	C[CH]CC(CC(=O)OO)OO	! Confirmed by translating name automatically
# R30C6H11OA	[CH2]CCCCC=O	! Confirmed by translating name automatically
# R310C6H11O7APPU	CC(CC(CC(=O)OO)OO)O[O]	! Confirmed by translating name automatically
# R31C6H11OA	C[CH]CCCC=O	! Confirmed by translating name automatically
# R32C6H11OA	CC[CH]CCC=O	! Confirmed by translating name automatically
# R33C6H11OA	CCC[CH]CC=O	! Confirmed by translating name automatically
# R34C6H11OA	CCCC[CH]C=O	! Confirmed by translating name automatically
# R35C6H11O2K	CCCCCC([O])=O	! Confirmed by translating name automatically
# R36C6H11O2B	[CH2]CCCCC(=O)O	! Confirmed by translating name automatically
# R37C6H11O2B	C[CH]CCCC(=O)O	! Confirmed by translating name automatically
# R38C6H11O2B	CC[CH]CCC(=O)O	! Confirmed by translating name automatically
# R39C6H11O2B	CCC[CH]CC(=O)O	! Confirmed by translating name automatically
# R3OOH	[O]O	! Confirmed by translating name automatically
# R40C6H11O2B	CCCC[CH]C(=O)O	! Confirmed by translating name automatically
# R41C3H7O2U	CCCO[O]	! Confirmed by translating name automatically
# R42C4H9O2U	CCCCO[O]	! Confirmed by translating name automatically
# R43C5H11O2U	CCC(CC)O[O]	! Confirmed by translating name automatically
# R44C5H11O2U	CCCCCO[O]	! Confirmed by translating name automatically
# R45C5H11O2U	CCCC(C)O[O]	! Confirmed by translating name automatically
# R46C6H11O3AU	[O]OCCCCCC=O	! Confirmed by translating name automatically
# R47C4H7OA	[CH2]CCC=O	! Confirmed by translating name automatically
# R48C6H11O3AU	CC(CCCC=O)O[O]	! Confirmed by translating name automatically
# R49C3H5OA	[CH2]CC=O	! Confirmed by translating name automatically
# R4CH3	[CH3]	! Confirmed by translating name automatically
# R50C6H11O3AU	CCC(CCC=O)O[O]	! Confirmed by translating name automatically
# R51C6H11O3AU	CCCC(CC=O)O[O]	! Confirmed by translating name automatically
# R52C6H11O3AU	CCCCC(C=O)O[O]	! Confirmed by translating name automatically
# R53C6H11O4UB	[O]OCCCCCC(=O)O	! Confirmed by translating name automatically
# R54C4H7O2B	[CH2]CCC(=O)O	! Confirmed by translating name automatically
# R55C6H11O4UB	CC(CCCC(=O)O)O[O]	! Confirmed by translating name automatically
# R56C3H5O2B	[CH2]CC(=O)O	! Confirmed by translating name automatically
# R57C6H11O4UB	CCC(CCC(=O)O)O[O]	! Confirmed by translating name automatically
# R58C6H11O4UB	CCCC(CC(=O)O)O[O]	! Confirmed by translating name automatically
# R59C6H11O4UB	CCCCC(O[O])C(=O)O	! Confirmed by translating name automatically
# R5CHO	[CH]=O	! Confirmed by translating name automatically
# R60C3H7O2P	C[CH]COO	! Confirmed by translating name automatically
# R61C3H7O2P	[CH2]CCOO	! Confirmed by translating name automatically
# R62C4H9O2P	CC[CH]COO	! Confirmed by translating name automatically
# R63C4H9O2P	C[CH]CCOO	! Confirmed by translating name automatically
# R64C4H9O2P	[CH2]CCCOO	! Confirmed by translating name automatically
# R65C5H11O2P	C[CH]C(CC)OO	! Confirmed by translating name automatically
# R66C5H11O2P	[CH2]CC(CC)OO	! Confirmed by translating name automatically
# R67C5H11O2P	CCC[CH]COO	! Confirmed by translating name automatically
# R68C5H11O2P	CC[CH]CCOO	! Confirmed by translating name automatically
# R69C5H11O2P	C[CH]CCCOO	! Confirmed by translating name automatically
# R6CH2OH	[CH2]O	! Confirmed by translating name automatically
# R70C5H11O2P	[CH2]CCCCOO	! Confirmed by translating name automatically
# R71C5H11O2P	[CH2]C(CCC)OO	! Confirmed by translating name automatically
# R72C5H11O2P	CC[CH]C(C)OO	! Confirmed by translating name automatically
# R73C5H11O2P	C[CH]CC(C)OO	! Confirmed by translating name automatically
# R74C5H11O2P	[CH2]CCC(C)OO	! Confirmed by translating name automatically
# R75C6H11O3AP	O=CCCC[CH]COO	! Confirmed by translating name automatically
# R76C6H11O3AP	O=CCC[CH]CCOO	! Confirmed by translating name automatically
# R77C6H11O3AP	O=CC[CH]CCCOO	! Confirmed by translating name automatically
# R78C6H11O3AP	O=C[CH]CCCCOO	! Confirmed by translating name automatically
# R79C4H7O3AU	[O]OCCCC=O	! Confirmed by translating name automatically
# R7CH3O	C[O]	! Confirmed by translating name automatically
# R80C4H7OK	CCC[C]=O	! Confirmed by translating name automatically
# R81C6H11O3AP	[CH2]C(CCCC=O)OO	! Confirmed by translating name automatically
# R82C6H11O3AP	CC([CH]CCC=O)OO	! Confirmed by translating name automatically
# R83C6H11O3AP	CC(C[CH]CC=O)OO	! Confirmed by translating name automatically
# R84C6H11O3AP	CC(CC[CH]C=O)OO	! Confirmed by translating name automatically
# R85C6H11O3KP	CC(CCC[C]=O)OO	! Confirmed by translating name automatically
# R86C3H5O3AU	[O]OCCC=O	! Confirmed by translating name automatically
# R87C6H11O3AP	C[CH]C(CCC=O)OO	! Confirmed by translating name automatically
# R88C6H11O3AP	[CH2]CC(CCC=O)OO	! Confirmed by translating name automatically
# R89C6H11O3AP	CCC([CH]CC=O)OO	! Confirmed by translating name automatically
# R8CH3OO	CO[O]	! Confirmed by translating name automatically
# R90C6H11O3AP	CCC(C[CH]C=O)OO	! Confirmed by translating name automatically
# R91C6H11O3KP	CCC(CC[C]=O)OO	! Confirmed by translating name automatically
# R92C6H11O3AP	CCCC([CH]C=O)OO	! Confirmed by translating name automatically
# R93C6H11O3KP	CCCC(C[C]=O)OO	! Confirmed by translating name automatically
# R94C6H11O3AP	CC[CH]C(CC=O)OO	! Confirmed by translating name automatically
# R95C6H11O3AP	C[CH]CC(CC=O)OO	! Confirmed by translating name automatically
# R96C6H11O3AP	[CH2]CCC(CC=O)OO	! Confirmed by translating name automatically
# R97C6H11O3KP	CCCCC([C]=O)OO	! Confirmed by translating name automatically
# R98C6H11O3AP	CCC[CH]C(C=O)OO	! Confirmed by translating name automatically
# R99C6H11O3AP	CC[CH]CC(C=O)OO	! Confirmed by translating name automatically
# R9C2HT	[C]#C	! Confirmed by translating name automatically
# dcaprolac	CC1CCCC(=O)O1	! Confirmed by translating name automatically
# gcaprolac	CCC1CCC(=O)O1	! Confirmed by translating name automatically

# %%
path = '../RMG-models/PCI2017/025-Sudholt/thermo.txt'
f = open(path, "r")
mech_lines = f.readlines()

# %%
import re

entries = []; # entries we care about: contain species name and atomic composition
for line in mech_lines[10:-1]:
    if re.match('^\s', line): continue
    if line[0] == '-': continue
    if line[0] == '!': continue
    entries.append(line)
entries
# Out:
# ['N2                000000N   2               G    300.00   5000.00 1000.00      1\n',
#  'H2                000000H   2               G    300.00   5000.00 1000.00      1\n',
#  'AR                000000AR  1               G    300.00   5000.00 1000.00      1\n',
#  'H                 000000H   1               G    300.00   5000.00 1000.00      1\n',
#  'HE                000000HE  1               G    300.00   5000.00 1000.00      1\n',
#  'O                 000000O   1               G    300.00   5000.00 1000.00      1\n',
#  'O2                000000O   2               G    300.00   5000.00 1000.00      1\n',
#  'OH                000000H   1O   1          G    300.00   5000.00 1000.00      1\n',
#  'HO2               000000H   1O   2          G    300.00   5000.00 1000.00      1\n',
#  'H2O               000000H   2O   1          G    300.00   5000.00 1000.00      1\n',
#  'C2H6              000000H   6C   2          G    300.00   5000.00 1000.00      1\n',
#  'C2H5              000000H   5C   2          G    300.00   5000.00 1000.00      1\n',
#  'H2O2              000000H   2O   2          G    300.00   5000.00 1000.00      1\n',
#  'C                 000000C   1               G    300.00   5000.00 1000.00      1\n',
#  'CO                000000O   1C   1          G    300.00   5000.00 1000.00      1\n',
#  'CH                000000H   1C   1          G    300.00   5000.00 1000.00      1\n',
#  'CH3               000000H   3C   1          G    300.00   5000.00 1000.00      1\n',
#  'CH2O              000000H   2O   1C   1     G    300.00   5000.00 1000.00      1\n',
#  'HCO               000000H   1O   1C   1     G    300.00   5000.00 1000.00      1\n',
#  'T-CH2             000000H   2C   1          G    300.00   5000.00 1000.00      1\n',
#  'S-CH2             000000H   2C   1          G    300.00   5000.00 1000.00      1\n',
#  'CH3OH             000000H   4O   1C   1     G    300.00   5000.00 1000.00      1\n',
#  'C2H2              000000H   2C   2          G    300.00   5000.00 1000.00      1\n',
#  'C2H               000000H   1C   2          G    300.00   5000.00 1000.00      1\n',
#  'CO2               000000O   2C   1          G    300.00   5000.00 1000.00      1\n',
#  'C2H4              000000H   4C   2          G    300.00   5000.00 1000.00      1\n',
#  'C2H3              000000H   3C   2          G    300.00   5000.00 1000.00      1\n',
#  'CH3O              000000H   3O   1C   1     G    300.00   5000.00 1000.00      1\n',
#  'CH4               000000H   4C   1          G    300.00   5000.00 1000.00      1\n',
#  'CH3O2             000000H   3O   2C   1     G    300.00   5000.00 1000.00      1\n',
#  'HCCO              000000H   1O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH2CO             000000H   2O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3CHO            000000H   4O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH2OH             000000H   3O   1C   1     G    300.00   5000.00 1000.00      1\n',
#  'OCHO              000000H   1O   2C   1     G    300.00   5000.00 1000.00      1\n',
#  'HOCHO             000000H   2O   2C   1     G    300.00   5000.00 1000.00      1\n',
#  'CH3O2H            000000H   4O   2C   1     G    300.00   5000.00 1000.00      1\n',
#  'HOCH2O            000000H   3O   2C   1     G    300.00   5000.00 1000.00      1\n',
#  'O2CHO             000000H   1O   3C   1     G    300.00   5000.00 1000.00      1\n',
#  'HO2CHO            000000H   2O   3C   1     G    300.00   5000.00 1000.00      1\n',
#  'C3H2O             000000H   2O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H3              000000H   3C   3          G    300.00   5000.00 1000.00      1\n',
#  'H2C2              000000H   2C   2          G    300.00   5000.00 1000.00      1\n',
#  'N-C4H3            000000H   3C   4          G    300.00   5000.00 1000.00      1\n',
#  'HCCOH             000000H   2O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'S-C3H5            000000H   5C   3          G    300.00   5000.00 1000.00      1\n',
#  'C4H4              000000H   4C   4          G    300.00   5000.00 1000.00      1\n',
#  'N-C4H5            000000H   5C   4          G    300.00   5000.00 1000.00      1\n',
#  'I-C4H5            000000H   5C   4          G    300.00   5000.00 1000.00      1\n',
#  'CH2CHO            000000H   3O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'A-C3H5            000000H   5C   3          G    300.00   5000.00 1000.00      1\n',
#  'C4H6              000000H   6C   4          G    300.00   5000.00 1000.00      1\n',
#  'C2H3CHO           000000H   4O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C2H4O1-2          000000H   4O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'C2H5O             000000H   5O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7            000000H   7C   3          G    300.00   5000.00 1000.00      1\n',
#  'C4H10             000000H  10C   4          G    300.00   5000.00 1000.00      1\n',
#  'C2O               000000O   1C   2          G    300.00   5000.00 1000.00      1\n',
#  'C2H3O1-2          000000H   3O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3CO             000000H   3O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'C2H4OH            000000H   5O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3CHOH           000000H   5O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3OCH2           000000H   5O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'C2H5OH            000000H   6O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3OCH3           000000H   6O   1C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3CO2            000000H   3O   2C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3OCO            000000H   3O   2C   2     G    300.00   5000.00 1000.00      1\n',
#  'C2H4O2H           000000H   5O   2C   2     G    300.00   5000.00 1000.00      1\n',
#  'C2H5O2            000000H   5O   2C   2     G    300.00   5000.00 1000.00      1\n',
#  'C2H5O2H           000000H   6O   2C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3CO3            000000H   3O   3C   2     G    300.00   5000.00 1000.00      1\n',
#  'CH3CO3H           000000H   4O   3C   2     G    300.00   5000.00 1000.00      1\n',
#  'O2C2H4OH          000000H   5O   3C   2     G    300.00   5000.00 1000.00      1\n',
#  'C3H2              000000H   2C   3          G    300.00   5000.00 1000.00      1\n',
#  'C4H2              000000H   2C   4          G    300.00   5000.00 1000.00      1\n',
#  'I-C4H3            000000H   3C   4          G    300.00   5000.00 1000.00      1\n',
#  'P-C3H4            000000H   4C   3          G    300.00   5000.00 1000.00      1\n',
#  'A-C3H4            000000H   4C   3          G    300.00   5000.00 1000.00      1\n',
#  'T-C3H5            000000H   5C   3          G    300.00   5000.00 1000.00      1\n',
#  'C3H5O             000000H   5O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6              000000H   6C   3          G    300.00   5000.00 1000.00      1\n',
#  'I-C3H7            000000H   7C   3          G    300.00   5000.00 1000.00      1\n',
#  'C3H8              000000H   8C   3          G    300.00   5000.00 1000.00      1\n',
#  'I-C3H7O           000000H   7O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7O           000000H   7O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C2H3CO            000000H   3O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH3CHCO           000000H   4O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C2H5CO            000000H   5O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH2CCH2OH         000000H   5O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH2CH2CHO         000000H   5O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH3COCH2          000000H   5O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C2H5CHO           000000H   6O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6O1-2          000000H   6O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6O1-3          000000H   6O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6OH            000000H   7O   1C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH3COCH2O         000000H   5O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'A-C3H5OOH         000000H   6O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6OOH1-2        000000H   7O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6OOH1-3        000000H   7O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6OOH2-1        000000H   7O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'I-C3H7O2          000000H   7O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7O2          000000H   7O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7O2H         000000H   8O   2C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH3COCH2O2        000000H   5O   3C   3     G    300.00   5000.00 1000.00      1\n',
#  'CH3COCH2O2H       000000H   6O   3C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3KET12           000000H   6O   3C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3KET13           000000H   6O   3C   3     G    300.00   5000.00 1000.00      1\n',
#  'HOC3H6O2          000000H   7O   3C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H52-1J3OOH      000000H   7O   4C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6OOH1-3O2      000000H   7O   4C   3     G    300.00   5000.00 1000.00      1\n',
#  'C3H6OOH1-2O2      000000H   7O   4C   3     G    300.00   5000.00 1000.00      1\n',
#  'C4H               000000H   1C   4          G    300.00   5000.00 1000.00      1\n',
#  'C6H2              000000H   2C   6          G    300.00   5000.00 1000.00      1\n',
#  'C8H2              000000H   2C   8          G    300.00   5000.00 1000.00      1\n',
#  'A1-C6H6           000000H   6C   6          G    300.00   5000.00 1000.00      1\n',
#  'C4H71-1           000000H   7C   4          G    300.00   5000.00 1000.00      1\n',
#  'C4H71-2           000000H   7C   4          G    300.00   5000.00 1000.00      1\n',
#  'C4H71-3           000000H   7C   4          G    300.00   5000.00 1000.00      1\n',
#  'C4H8-1            000000H   8C   4          G    300.00   5000.00 1000.00      1\n',
#  'C4H8-2            000000H   8C   4          G    300.00   5000.00 1000.00      1\n',
#  'C4H7O             000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H71-4           000000H   7C   4          G    300.00   5000.00 1000.00      1\n',
#  'C6H12-1           000000H  12C   6          G    300.00   5000.00 1000.00      1\n',
#  'C4H8O1-2          000000H   8O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'P-C4H9            000000H   9C   4          G    300.00   5000.00 1000.00      1\n',
#  'N-C7H16           000000H  16C   7          G    300.00   5000.00 1000.00      1\n',
#  'P-C4H9O           000000H   9O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'S-C4H9            000000H   9C   4          G    300.00   5000.00 1000.00      1\n',
#  'A-C3H5CHO         000000H   6O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C2H3COCH3         000000H   6O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C2H5CHCO          000000H   6O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C2H5COCH2         000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C2H5COCH3         000000H   8O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C3H6CHO-1         000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C3H6CHO-2         000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C3H6CHO-3         000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'CH2CH2COCH3       000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'CH3CHCOCH3        000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7CO          000000H   7O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H8O1-3          000000H   8O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7CHO         000000H   8O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'P-C4H8OH          000000H   9O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H8OH-1O2        000000H   9O   3C   4     G    300.00   5000.00 1000.00      1\n',
#  'S-C4H8OH          000000H   9O   1C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H8OH-2O2        000000H   9O   3C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H8OOH1-2        000000H   9O   2C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H8OOH1-3        000000H   9O   2C   4     G    300.00   5000.00 1000.00      1\n',
#  'P-C4H9O2          000000H   9O   2C   4     G    300.00   5000.00 1000.00      1\n',
#  'P-C4H9O2H         000000H  10O   2C   4     G    300.00   5000.00 1000.00      1\n',
#  'NC4KET13          000000H   8O   3C   4     G    300.00   5000.00 1000.00      1\n',
#  'C4H8OOH1-3O2      000000H   9O   4C   4     G    300.00   5000.00 1000.00      1\n',
#  'C5H81-3           000000H   8C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H81-4           000000H   8C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H91-3           000000H   9C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H9O1-3          000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10-2           000000H  10C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H91-4           000000H   9C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H10-1           000000H  10C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H91-5           000000H   9C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H92-4           000000H   9C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H92-5           000000H   9C   5          G    300.00   5000.00 1000.00      1\n',
#  'C6H12-2           000000H  12C   6          G    300.00   5000.00 1000.00      1\n',
#  'C5H11-2           000000H  11C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H11-1           000000H  11C   5          G    300.00   5000.00 1000.00      1\n',
#  'C5H11O-1          000000H  11O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'P-C2H4COC2H3      000000H   7O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C2H5COC2H3        000000H   8O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C2H5COC2H4P       000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C2H5COC2H5        000000H  10O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C3H6COCH3-1       000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C3H6COCH3-2       000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C4H8CHO-1         000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C4H8CHO-2         000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C4H8CHO-3         000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C4H8CHO-4         000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7COCH2       000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'N-C3H7COCH3       000000H  10O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'N-C4H9CO          000000H   9O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10O1-3         000000H  10O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10O1-4         000000H  10O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'N-C4H9CHO         000000H  10O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10OH-1         000000H  11O   1C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10OOH1-2       000000H  11O   2C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10OOH1-3       000000H  11O   2C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10OOH1-4       000000H  11O   2C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H11O2-1         000000H  11O   2C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H11O2H-1        000000H  12O   2C   5     G    300.00   5000.00 1000.00      1\n',
#  'NC5KET13          000000H  10O   3C   5     G    300.00   5000.00 1000.00      1\n',
#  'O2C5H10OH-1       000000H  11O   3C   5     G    300.00   5000.00 1000.00      1\n',
#  'C5H10OOH1-3O2     000000H  11O   4C   5     G    300.00   5000.00 1000.00      1\n',
#  'C6H101-3          000000H  10C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H101OOH4-3      000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H111-3          000000H  11C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H101-4          000000H  10C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H101-5          000000H  10C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H111-5          000000H  11C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H11O1-3         000000H  11O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H112O2-1        000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H111O2-3        000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H111-6          000000H  11C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H111-4          000000H  11C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H111O2-4        000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H111O2H-4       000000H  12O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H111O2-5        000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H111O2-6        000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12OOH1-2       000000H  13O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12OH-1         000000H  13O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12-3           000000H  12C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H13-1           000000H  13C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H13O-1          000000H  13O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H13-2           000000H  13C   6          G    300.00   5000.00 1000.00      1\n',
#  'C6H13-3           000000H  13C   6          G    300.00   5000.00 1000.00      1\n',
#  'VTHF              000000H  10O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'NC3H7COC2H4P      000000H  11O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12O1-3         000000H  12O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12O1-4         000000H  12O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'O2C6H12OH-1       000000H  13O   3C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H101OOH3-5      000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'MVOX              000000H  10O   1C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H101OOH5-3      000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H101OOH6-3      000000H  11O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12OOH1-3       000000H  13O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12OOH1-4       000000H  13O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H13O2-1         000000H  13O   2C   6     G    300.00   5000.00 1000.00      1\n',
#  'NC6KET13          000000H  12O   3C   6     G    300.00   5000.00 1000.00      1\n',
#  'C6H12OOH1-3O2     000000H  13O   4C   6     G    300.00   5000.00 1000.00      1\n',
#  'C*COH             020613H   4C   2O   1    0G   300.000  2500.0001000.000      1\n',
#  'GVLR-4            031013H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'GVLR-5            031013H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'GVLR-3            031013H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'GVLR-2            031013H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'GVL               031013H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCCC(*O)OH      060613H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C2C*O             082613H   6C   3O   1    0G   300.000  2500.0001000.000      1\n',
#  'C-C*CCJCC(*O)OH   081913H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCCC(*O)OJ      081813H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCCJC(*O)OH     081813H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'T-CC*CCC(*O)OH    083113H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCC*C(OH)2      092313H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCC*C*O         092913H   6C   5O   1    0G   300.000  2500.0001000.000      1\n',
#  'T-CC*CCJ          102312H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CJ(*O)OH          083013H   1C   1O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJC(*O)OH         080613H   3C   2O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCJCCC(*O)OH     092613H  11C   6O   2    0G   300.000  2500.0001000.000      1\n',
#  'C2JCOC(*C)OH      100313H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJCC(C)OCHO       090113H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(OJ)CCCHO       100213H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCCC(*O)OJ       090113H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCJCC(*O)OH      090113H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJCCCC(*O)OH      081813H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCCJC(*O)OH      090113H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCC(C)OCJ(*O)     091213H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCC(CJ)OCHO       092613H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCJC(C)OCHO       100213H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(OH)CCCJ(*O)    100413H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(OH)CCJCHO      100513H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(OH)CJCCHO      100613H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCJ(OH)CCCHO      100613H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJC(OH)CCCHO      100513H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C2COC(*C)OJ       100513H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCCC(OJ)OH      082913H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCJCCOCHO         092213H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCJCOCHO         100413H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCJ(C)OCHO       100113H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCCCJ(OH)2      082913H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C-CC*CCC(*O)OH    092313H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCJOCHO           100413H   5C   3O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(*O)CCCHO       100313H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'OHCCCCHO          081713H   6C   4O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CCC(*O)OH       100413H   6C   4O   2    0G   300.000  2500.0001000.000      1\n',
#  'C-CCC*CC(*O)OH    100513H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'T-CCC*CC(*O)OH    100513H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJCC(*O)OH        082813H   5C   3O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCCC*C*O          100513H   8C   5O   1    0G   300.000  2500.0001000.000      1\n',
#  'CCC(*C)OCHO       100513H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C-CC*CC           021713H   8C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'T-CC*CC           021713H   8C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C*CC(C)OH         100613H   8C   4O   1    0G   300.000  2500.0001000.000      1\n',
#  'C2COJ             072313H   7C   3O   1    0G   300.000  2500.0001000.000      1\n',
#  'C*CCCCHO          083113H   8C   5O   1    0G   300.000  2500.0001000.000      1\n',
#  'HC(*O)OCJ         091313H   3C   2O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*C(OH)2          083013H   4C   2O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJCC(C)OH         100213H   9C   4O   1    0G   300.000  2500.0001000.000      1\n',
#  'CCJCCC(*O)OH      081913H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCC(C)(OJ)HCO     100613H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(OH)CC*C*O      100713H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CY(C*CC)          062912H   4C   3    0    0G   300.000  2500.0001000.000      1\n',
#  'CY(CJCC)          072412H   5C   3    0    0G   300.000  2500.0001000.000      1\n',
#  'C*C(C)OH          052813H   6C   3O   1    0G   300.000  2500.0001000.000      1\n',
#  'C2CJOH            101013H   7C   3O   1    0G   300.000  2500.0001000.000      1\n',
#  'C2JCOH            072313H   7C   3O   1    0G   300.000  2500.0001000.000      1\n',
#  'C-CC*CCJ          102312H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C*COC(*O)CJ       031613H   5C   4O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*CC(C)OCJ(*O)    082813H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*C(C)OC(*O)CJ    082713H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC(*O)CCCJ(*O)    082713H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJCC(*O)C         082813H   7C   4O   1    0G   300.000  2500.0001000.000      1\n',
#  'OHCCCCJ(*O)       031813H   5C   4O   2    0G   300.000  2500.0001000.000      1\n',
#  'C2JCCCC(*O)OH     092613H  11C   6O   2    0G   300.000  2500.0001000.000      1\n',
#  'CC#C              070512H   4C   3    0    0G   300.000  2500.0001000.000      1\n',
#  'CC*CJC            101413H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C*CC2J            080613H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C2C*CJ            101413H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CC*C*C            101413H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CCC#C             101512H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CC#CC             101512H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CY(CJCCC)         070612H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CY(C*CCC)         101413H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C#CCJC            101613H   5C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C#CCCJ            101613H   5C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CC#CCJ            102513H   5C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'O*CY(COCJCC)      030413H   5C   4O   2    0G   300.000  2500.0001000.000      1\n',
#  'O*CY(CCO)         061812H   2C   2O   2    0G   300.000  2500.0001000.000      1\n',
#  'T-C*CCJCC(*O)OH   081913H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'HOCY(CJOC(C)CC)   080713H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'JOCY(COC(C)CC)    083013H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CCY(COCJOCC)      090113H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C2COCY(CJCO)      100613H   9C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'HOCY(C*CCC(C)O)   081613H   8C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'ACEOH             100913H   4C   2O   2    0G   300.000  2500.0001000.000      1\n',
#  'O*CY(COC*CC)      030613H   4C   4O   2    0G   300.000  2500.0001000.000      1\n',
#  'O*CY(COC(C)C*C)   072613H   6C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'O*CY(COC(C)*CC)   072813H   6C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'CJCY(CCC)         070612H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CCY(CJCC)         070612H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CCY(CCJC)         070612H   7C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'C*CY(CCC)         101413H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CCY(C*CC)         101413H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'CCY(CC*C)         101413H   6C   4    0    0G   300.000  2500.0001000.000      1\n',
#  'OJC(C)CCCHO        THERMC   5H   9O   2    0G   300.000  5000.000 1323.000    41\n',
#  'O*C*CCC(C)OJ 12/15 THERMC   5H   7O   2    0G   300.000  5000.000 1685.000    31\n',
#  'C*CC(*O)OCJC 12/15 THERMC   5H   7O   2    0G   300.000  5000.000 1404.000    31\n',
#  'CC*CCC(*O)OJ    15 THERMC   5H   7O   2    0G   300.000  5000.000 1374.000    31\n',
#  'C*CC(C)OC*JO 12/15 THERMC   5H   7O   2    0G   300.000  5000.000 1376.000    41\n',
#  'O*CY(COC*CCJ)    5 THERMC   4H   3O   2    0G   300.000  5000.000 1437.000    01\n',
#  'O*CY(COCJ(C)C*C) 5 THERMC   5H   5O   2    0G   300.000  5000.000 1397.000    11\n',
#  'O*CY(COC*(C)CCJ)   THERMC   5H   5O   2    0G   300.000  5000.000 1512.000    11\n',
#  'gvlr-2(3oh)             C   5H   7O   3    0G   300.000  5000.000 1407.000    21\n',
#  'gvlr-4(3oh)             C   5H   7O   3    0G   300.000  5000.000 1427.000    21\n',
#  'O*CY(COCJC(OH)C)   THERMC   4H   5O   3    0G   300.000  5000.000 1411.000    11\n',
#  'O*CJC*CC(*O)C   15 THERMC   5H   5O   2    0G   300.000  5000.000 1398.000    11\n',
#  'O*C*CC*C(C)OJ   15 THERMC   5H   5O   2    0G   300.000  5000.000 1392.000    11\n',
#  'O*C*CC*COJ      15 THERMC   4H   3O   2    0G   300.000  5000.000 1402.000    01\n',
#  'CHCHCHO    8/18/15 THERMC   3H   3O   1    0G   300.000  5000.000 1394.000    01\n',
#  'CHCHCOCH3  8/18/15 THERMC   4H   5O   1    0G   300.000  5000.000 1395.000    11\n',
#  'HCOHCO            000000H   2O   2C   2     G    300.00   5000.00 1000.00      1\n',
#  'O*CY(COCJ(C)CC)   121114H   7C   5O   2    0G   300.000  2500.0001000.000      1\n',
#  'C*COC(*O)CCJ      090113H   7C   5O   2    0G   300.000  2500.0001000.000      1   \n']

# %%
# dictionary of dictionaries for entries:
    # 1st value is name of species
    # 1st key is dictionary for atomic composition
        # 2nd value is element
        # 2nd key is number of atoms
entries_dict = {}

errors_dict = {}
errors_names = []

for entry in entries:
    name = re.match('([^\s]+)\s', entry).group(1)
    not_name = entry[24:].strip()
    print name
    print not_name
    
    elements = []
    num_atoms = []
    for i in range(len(not_name.split())):
        string = not_name.split()[i]
        if re.search('[GLgl]', string) or len(string) > 3:
            break
        m = re.search("[a-zA-z]+", string) # find elements
        if not m:
            continue
        elements.append(m.group())
        m = re.search("\d+", not_name.split()[i+1]) # find corresponding number of atoms
        num = int(m.group())
        num_atoms.append(num)
        
        # if more than 10 atoms of same element in molecule, check for errors:
        if num >= 10:
            guess = 0
            # guess how many atoms should be present from name:
            for s in re.findall(elements[-1]+'(\d*)', name):
                if s: guess += int(s)
                else: guess += 1
            if num > guess:
                print "!!! POTENTIAL ERROR: too many {}".format(elements[-1])
                errors_names.append(name)
            
    entries_dict[name] = dict(zip(elements, num_atoms))
    if name in errors_names:
        errors_dict[name] = dict(zip(elements, num_atoms))
    print entries_dict[name]
    print ""
# Out:
# N2
# N   2               G    300.00   5000.00 1000.00      1
# {'N': 2}
#
# H2
# H   2               G    300.00   5000.00 1000.00      1
# {'H': 2}
#
# AR
# AR  1               G    300.00   5000.00 1000.00      1
# {'AR': 1}
#
# H
# H   1               G    300.00   5000.00 1000.00      1
# {'H': 1}
#
# HE
# HE  1               G    300.00   5000.00 1000.00      1
# {'HE': 1}
#
# O
# O   1               G    300.00   5000.00 1000.00      1
# {'O': 1}
#
# O2
# O   2               G    300.00   5000.00 1000.00      1
# {'O': 2}
#
# OH
# H   1O   1          G    300.00   5000.00 1000.00      1
# {'H': 1, 'O': 1}
#
# HO2
# H   1O   2          G    300.00   5000.00 1000.00      1
# {'H': 1, 'O': 2}
#
# H2O
# H   2O   1          G    300.00   5000.00 1000.00      1
# {'H': 2, 'O': 1}
#
# C2H6
# H   6C   2          G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 2}
#
# C2H5
# H   5C   2          G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2}
#
# H2O2
# H   2O   2          G    300.00   5000.00 1000.00      1
# {'H': 2, 'O': 2}
#
# C
# C   1               G    300.00   5000.00 1000.00      1
# {'C': 1}
#
# CO
# O   1C   1          G    300.00   5000.00 1000.00      1
# {'C': 1, 'O': 1}
#
# CH
# H   1C   1          G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 1}
#
# CH3
# H   3C   1          G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 1}
#
# CH2O
# H   2O   1C   1     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 1, 'O': 1}
#
# HCO
# H   1O   1C   1     G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 1, 'O': 1}
#
# T-CH2
# H   2C   1          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 1}
#
# S-CH2
# H   2C   1          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 1}
#
# CH3OH
# H   4O   1C   1     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 1, 'O': 1}
#
# C2H2
# H   2C   2          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 2}
#
# C2H
# H   1C   2          G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 2}
#
# CO2
# O   2C   1          G    300.00   5000.00 1000.00      1
# {'C': 1, 'O': 2}
#
# C2H4
# H   4C   2          G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 2}
#
# C2H3
# H   3C   2          G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2}
#
# CH3O
# H   3O   1C   1     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 1, 'O': 1}
#
# CH4
# H   4C   1          G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 1}
#
# CH3O2
# H   3O   2C   1     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 1, 'O': 2}
#
# HCCO
# H   1O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 2, 'O': 1}
#
# CH2CO
# H   2O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 2, 'O': 1}
#
# CH3CHO
# H   4O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 2, 'O': 1}
#
# CH2OH
# H   3O   1C   1     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 1, 'O': 1}
#
# OCHO
# H   1O   2C   1     G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 1, 'O': 2}
#
# HOCHO
# H   2O   2C   1     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 1, 'O': 2}
#
# CH3O2H
# H   4O   2C   1     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 1, 'O': 2}
#
# HOCH2O
# H   3O   2C   1     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 1, 'O': 2}
#
# O2CHO
# H   1O   3C   1     G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 1, 'O': 3}
#
# HO2CHO
# H   2O   3C   1     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 1, 'O': 3}
#
# C3H2O
# H   2O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 3, 'O': 1}
#
# C3H3
# H   3C   3          G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 3}
#
# H2C2
# H   2C   2          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 2}
#
# N-C4H3
# H   3C   4          G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 4}
#
# HCCOH
# H   2O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 2, 'O': 1}
#
# S-C3H5
# H   5C   3          G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3}
#
# C4H4
# H   4C   4          G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 4}
#
# N-C4H5
# H   5C   4          G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 4}
#
# I-C4H5
# H   5C   4          G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 4}
#
# CH2CHO
# H   3O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2, 'O': 1}
#
# A-C3H5
# H   5C   3          G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3}
#
# C4H6
# H   6C   4          G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 4}
#
# C2H3CHO
# H   4O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 3, 'O': 1}
#
# C2H4O1-2
# H   4O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 2, 'O': 1}
#
# C2H5O
# H   5O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 1}
#
# N-C3H7
# H   7C   3          G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3}
#
# C4H10
# H  10C   4          G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 4}
#
# C2O
# O   1C   2          G    300.00   5000.00 1000.00      1
# {'C': 2, 'O': 1}
#
# C2H3O1-2
# H   3O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2, 'O': 1}
#
# CH3CO
# H   3O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2, 'O': 1}
#
# C2H4OH
# H   5O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 1}
#
# CH3CHOH
# H   5O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 1}
#
# CH3OCH2
# H   5O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 1}
#
# C2H5OH
# H   6O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 2, 'O': 1}
#
# CH3OCH3
# H   6O   1C   2     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 2, 'O': 1}
#
# CH3CO2
# H   3O   2C   2     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2, 'O': 2}
#
# CH3OCO
# H   3O   2C   2     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2, 'O': 2}
#
# C2H4O2H
# H   5O   2C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 2}
#
# C2H5O2
# H   5O   2C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 2}
#
# C2H5O2H
# H   6O   2C   2     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 2, 'O': 2}
#
# CH3CO3
# H   3O   3C   2     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 2, 'O': 3}
#
# CH3CO3H
# H   4O   3C   2     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 2, 'O': 3}
#
# O2C2H4OH
# H   5O   3C   2     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 2, 'O': 3}
#
# C3H2
# H   2C   3          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 3}
#
# C4H2
# H   2C   4          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 4}
#
# I-C4H3
# H   3C   4          G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 4}
#
# P-C3H4
# H   4C   3          G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 3}
#
# A-C3H4
# H   4C   3          G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 3}
#
# T-C3H5
# H   5C   3          G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3}
#
# C3H5O
# H   5O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 1}
#
# C3H6
# H   6C   3          G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3}
#
# I-C3H7
# H   7C   3          G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3}
#
# C3H8
# H   8C   3          G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 3}
#
# I-C3H7O
# H   7O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 1}
#
# N-C3H7O
# H   7O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 1}
#
# C2H3CO
# H   3O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 3, 'C': 3, 'O': 1}
#
# CH3CHCO
# H   4O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 4, 'C': 3, 'O': 1}
#
# C2H5CO
# H   5O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 1}
#
# CH2CCH2OH
# H   5O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 1}
#
# CH2CH2CHO
# H   5O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 1}
#
# CH3COCH2
# H   5O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 1}
#
# C2H5CHO
# H   6O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 1}
#
# C3H6O1-2
# H   6O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 1}
#
# C3H6O1-3
# H   6O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 1}
#
# C3H6OH
# H   7O   1C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 1}
#
# CH3COCH2O
# H   5O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 2}
#
# A-C3H5OOH
# H   6O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 2}
#
# C3H6OOH1-2
# H   7O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 2}
#
# C3H6OOH1-3
# H   7O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 2}
#
# C3H6OOH2-1
# H   7O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 2}
#
# I-C3H7O2
# H   7O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 2}
#
# N-C3H7O2
# H   7O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 2}
#
# N-C3H7O2H
# H   8O   2C   3     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 3, 'O': 2}
#
# CH3COCH2O2
# H   5O   3C   3     G    300.00   5000.00 1000.00      1
# {'H': 5, 'C': 3, 'O': 3}
#
# CH3COCH2O2H
# H   6O   3C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 3}
#
# C3KET12
# H   6O   3C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 3}
#
# C3KET13
# H   6O   3C   3     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 3, 'O': 3}
#
# HOC3H6O2
# H   7O   3C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 3}
#
# C3H52-1J3OOH
# H   7O   4C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 4}
#
# C3H6OOH1-3O2
# H   7O   4C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 4}
#
# C3H6OOH1-2O2
# H   7O   4C   3     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 3, 'O': 4}
#
# C4H
# H   1C   4          G    300.00   5000.00 1000.00      1
# {'H': 1, 'C': 4}
#
# C6H2
# H   2C   6          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 6}
#
# C8H2
# H   2C   8          G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 8}
#
# A1-C6H6
# H   6C   6          G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 6}
#
# C4H71-1
# H   7C   4          G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4}
#
# C4H71-2
# H   7C   4          G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4}
#
# C4H71-3
# H   7C   4          G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4}
#
# C4H8-1
# H   8C   4          G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4}
#
# C4H8-2
# H   8C   4          G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4}
#
# C4H7O
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# C4H71-4
# H   7C   4          G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4}
#
# C6H12-1
# H  12C   6          G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 6}
#
# C4H8O1-2
# H   8O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4, 'O': 1}
#
# P-C4H9
# H   9C   4          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4}
#
# N-C7H16
# H  16C   7          G    300.00   5000.00 1000.00      1
# {'H': 16, 'C': 7}
#
# P-C4H9O
# H   9O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 1}
#
# S-C4H9
# H   9C   4          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4}
#
# A-C3H5CHO
# H   6O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 4, 'O': 1}
#
# C2H3COCH3
# H   6O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 4, 'O': 1}
#
# C2H5CHCO
# H   6O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 6, 'C': 4, 'O': 1}
#
# C2H5COCH2
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# C2H5COCH3
# H   8O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4, 'O': 1}
#
# C3H6CHO-1
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# C3H6CHO-2
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# C3H6CHO-3
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# CH2CH2COCH3
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# CH3CHCOCH3
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# N-C3H7CO
# H   7O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 4, 'O': 1}
#
# C4H8O1-3
# H   8O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4, 'O': 1}
#
# N-C3H7CHO
# H   8O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4, 'O': 1}
#
# P-C4H8OH
# H   9O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 1}
#
# C4H8OH-1O2
# H   9O   3C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 3}
#
# S-C4H8OH
# H   9O   1C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 1}
#
# C4H8OH-2O2
# H   9O   3C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 3}
#
# C4H8OOH1-2
# H   9O   2C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 2}
#
# C4H8OOH1-3
# H   9O   2C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 2}
#
# P-C4H9O2
# H   9O   2C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 2}
#
# P-C4H9O2H
# H  10O   2C   4     G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 4, 'O': 2}
#
# NC4KET13
# H   8O   3C   4     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 4, 'O': 3}
#
# C4H8OOH1-3O2
# H   9O   4C   4     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 4, 'O': 4}
#
# C5H81-3
# H   8C   5          G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 5}
#
# C5H81-4
# H   8C   5          G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 5}
#
# C5H91-3
# H   9C   5          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5}
#
# C5H9O1-3
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C5H10-2
# H  10C   5          G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5}
#
# C5H91-4
# H   9C   5          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5}
#
# C5H10-1
# H  10C   5          G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5}
#
# C5H91-5
# H   9C   5          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5}
#
# C5H92-4
# H   9C   5          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5}
#
# C5H92-5
# H   9C   5          G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5}
#
# C6H12-2
# H  12C   6          G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 6}
#
# C5H11-2
# H  11C   5          G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5}
#
# C5H11-1
# H  11C   5          G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5}
#
# C5H11O-1
# H  11O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 1}
#
# P-C2H4COC2H3
# H   7O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 7, 'C': 5, 'O': 1}
#
# C2H5COC2H3
# H   8O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 8, 'C': 5, 'O': 1}
#
# C2H5COC2H4P
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C2H5COC2H5
# H  10O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5, 'O': 1}
#
# C3H6COCH3-1
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C3H6COCH3-2
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C4H8CHO-1
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C4H8CHO-2
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C4H8CHO-3
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C4H8CHO-4
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# N-C3H7COCH2
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# N-C3H7COCH3
# H  10O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5, 'O': 1}
#
# N-C4H9CO
# H   9O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 9, 'C': 5, 'O': 1}
#
# C5H10O1-3
# H  10O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5, 'O': 1}
#
# C5H10O1-4
# H  10O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5, 'O': 1}
#
# N-C4H9CHO
# H  10O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 5, 'O': 1}
#
# C5H10OH-1
# H  11O   1C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 1}
#
# C5H10OOH1-2
# H  11O   2C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 2}
#
# C5H10OOH1-3
# H  11O   2C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 2}
#
# C5H10OOH1-4
# H  11O   2C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 2}
#
# C5H11O2-1
# H  11O   2C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 2}
#
# C5H11O2H-1
# H  12O   2C   5     G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 5, 'O': 2}
#
# NC5KET13
# H  10O   3C   5     G    300.00   5000.00 1000.00      1
# !!! POTENTIAL ERROR: too many H
# {'H': 10, 'C': 5, 'O': 3}
#
# O2C5H10OH-1
# H  11O   3C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 3}
#
# C5H10OOH1-3O2
# H  11O   4C   5     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 5, 'O': 4}
#
# C6H101-3
# H  10C   6          G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 6}
#
# C6H101OOH4-3
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H111-3
# H  11C   6          G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6}
#
# C6H101-4
# H  10C   6          G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 6}
#
# C6H101-5
# H  10C   6          G    300.00   5000.00 1000.00      1
# {'H': 10, 'C': 6}
#
# C6H111-5
# H  11C   6          G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6}
#
# C6H11O1-3
# H  11O   1C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 1}
#
# C6H112O2-1
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H111O2-3
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H111-6
# H  11C   6          G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6}
#
# C6H111-4
# H  11C   6          G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6}
#
# C6H111O2-4
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H111O2H-4
# H  12O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 6, 'O': 2}
#
# C6H111O2-5
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H111O2-6
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H12OOH1-2
# H  13O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 2}
#
# C6H12OH-1
# H  13O   1C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 1}
#
# C6H12-3
# H  12C   6          G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 6}
#
# C6H13-1
# H  13C   6          G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6}
#
# C6H13O-1
# H  13O   1C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 1}
#
# C6H13-2
# H  13C   6          G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6}
#
# C6H13-3
# H  13C   6          G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6}
#
# VTHF
# H  10O   1C   6     G    300.00   5000.00 1000.00      1
# !!! POTENTIAL ERROR: too many H
# {'H': 10, 'C': 6, 'O': 1}
#
# NC3H7COC2H4P
# H  11O   1C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 1}
#
# C6H12O1-3
# H  12O   1C   6     G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 6, 'O': 1}
#
# C6H12O1-4
# H  12O   1C   6     G    300.00   5000.00 1000.00      1
# {'H': 12, 'C': 6, 'O': 1}
#
# O2C6H12OH-1
# H  13O   3C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 3}
#
# C6H101OOH3-5
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# MVOX
# H  10O   1C   6     G    300.00   5000.00 1000.00      1
# !!! POTENTIAL ERROR: too many H
# {'H': 10, 'C': 6, 'O': 1}
#
# C6H101OOH5-3
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H101OOH6-3
# H  11O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 11, 'C': 6, 'O': 2}
#
# C6H12OOH1-3
# H  13O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 2}
#
# C6H12OOH1-4
# H  13O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 2}
#
# C6H13O2-1
# H  13O   2C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 2}
#
# NC6KET13
# H  12O   3C   6     G    300.00   5000.00 1000.00      1
# !!! POTENTIAL ERROR: too many H
# {'H': 12, 'C': 6, 'O': 3}
#
# C6H12OOH1-3O2
# H  13O   4C   6     G    300.00   5000.00 1000.00      1
# {'H': 13, 'C': 6, 'O': 4}
#
# C*COH
# H   4C   2O   1    0G   300.000  2500.0001000.000      1
# {'H': 4, 'C': 2, 'O': 1}
#
# GVLR-4
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# GVLR-5
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# GVLR-3
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# GVLR-2
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# GVL
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# C*CCCC(*O)OH
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# C2C*O
# H   6C   3O   1    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 3, 'O': 1}
#
# C-C*CCJCC(*O)OH
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# C*CCCC(*O)OJ
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# C*CCCJC(*O)OH
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# T-CC*CCC(*O)OH
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# C*CCC*C(OH)2
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# C*CCC*C*O
# H   6C   5O   1    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 5, 'O': 1}
#
# T-CC*CCJ
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# CJ(*O)OH
# H   1C   1O   2    0G   300.000  2500.0001000.000      1
# {'H': 1, 'C': 1, 'O': 2}
#
# CJC(*O)OH
# H   3C   2O   2    0G   300.000  2500.0001000.000      1
# {'H': 3, 'C': 2, 'O': 2}
#
# CCCJCCC(*O)OH
# H  11C   6O   2    0G   300.000  2500.0001000.000      1
# !!! POTENTIAL ERROR: too many H
# {'H': 11, 'C': 6, 'O': 2}
#
# C2JCOC(*C)OH
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CJCC(C)OCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CC(OJ)CCCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCCCC(*O)OJ
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCCJCC(*O)OH
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CJCCCC(*O)OH
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCCCJC(*O)OH
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCC(C)OCJ(*O)
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCC(CJ)OCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCJC(C)OCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CC(OH)CCCJ(*O)
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CC(OH)CCJCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CC(OH)CJCCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCJ(OH)CCCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CJC(OH)CCCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# C2COC(*C)OJ
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# C*CCCC(OJ)OH
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCJCCOCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCCJCOCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCCJ(C)OCHO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# C*CCCCJ(OH)2
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# C-CC*CCC(*O)OH
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# CCJOCHO
# H   5C   3O   2    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 3, 'O': 2}
#
# CC(*O)CCCHO
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# OHCCCCHO
# H   6C   4O   2    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4, 'O': 2}
#
# C*CCC(*O)OH
# H   6C   4O   2    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4, 'O': 2}
#
# C-CCC*CC(*O)OH
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# T-CCC*CC(*O)OH
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# CJCC(*O)OH
# H   5C   3O   2    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 3, 'O': 2}
#
# CCCC*C*O
# H   8C   5O   1    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 1}
#
# CCC(*C)OCHO
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# C-CC*CC
# H   8C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 4}
#
# T-CC*CC
# H   8C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 4}
#
# C*CC(C)OH
# H   8C   4O   1    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 4, 'O': 1}
#
# C2COJ
# H   7C   3O   1    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 3, 'O': 1}
#
# C*CCCCHO
# H   8C   5O   1    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 1}
#
# HC(*O)OCJ
# H   3C   2O   2    0G   300.000  2500.0001000.000      1
# {'H': 3, 'C': 2, 'O': 2}
#
# C*C(OH)2
# H   4C   2O   2    0G   300.000  2500.0001000.000      1
# {'H': 4, 'C': 2, 'O': 2}
#
# CJCC(C)OH
# H   9C   4O   1    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 4, 'O': 1}
#
# CCJCCC(*O)OH
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCC(C)(OJ)HCO
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CC(OH)CC*C*O
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# CY(C*CC)
# H   4C   3    0    0G   300.000  2500.0001000.000      1
# {'H': 4, 'C': 3}
#
# CY(CJCC)
# H   5C   3    0    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 3}
#
# C*C(C)OH
# H   6C   3O   1    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 3, 'O': 1}
#
# C2CJOH
# H   7C   3O   1    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 3, 'O': 1}
#
# C2JCOH
# H   7C   3O   1    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 3, 'O': 1}
#
# C-CC*CCJ
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# C*COC(*O)CJ
# H   5C   4O   2    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 4, 'O': 2}
#
# C*CC(C)OCJ(*O)
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# C*C(C)OC(*O)CJ
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# CC(*O)CCCJ(*O)
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# CJCC(*O)C
# H   7C   4O   1    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4, 'O': 1}
#
# OHCCCCJ(*O)
# H   5C   4O   2    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 4, 'O': 2}
#
# C2JCCCC(*O)OH
# H  11C   6O   2    0G   300.000  2500.0001000.000      1
# !!! POTENTIAL ERROR: too many H
# {'H': 11, 'C': 6, 'O': 2}
#
# CC#C
# H   4C   3    0    0G   300.000  2500.0001000.000      1
# {'H': 4, 'C': 3}
#
# CC*CJC
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# C*CC2J
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# C2C*CJ
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# CC*C*C
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# CCC#C
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# CC#CC
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# CY(CJCCC)
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# CY(C*CCC)
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# C#CCJC
# H   5C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 4}
#
# C#CCCJ
# H   5C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 4}
#
# CC#CCJ
# H   5C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 4}
#
# O*CY(COCJCC)
# H   5C   4O   2    0G   300.000  2500.0001000.000      1
# {'H': 5, 'C': 4, 'O': 2}
#
# O*CY(CCO)
# H   2C   2O   2    0G   300.000  2500.0001000.000      1
# {'H': 2, 'C': 2, 'O': 2}
#
# T-C*CCJCC(*O)OH
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# HOCY(CJOC(C)CC)
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# JOCY(COC(C)CC)
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# CCY(COCJOCC)
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# C2COCY(CJCO)
# H   9C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 9, 'C': 5, 'O': 2}
#
# HOCY(C*CCC(C)O)
# H   8C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 8, 'C': 5, 'O': 2}
#
# ACEOH
# H   4C   2O   2    0G   300.000  2500.0001000.000      1
# {'H': 4, 'C': 2, 'O': 2}
#
# O*CY(COC*CC)
# H   4C   4O   2    0G   300.000  2500.0001000.000      1
# {'H': 4, 'C': 4, 'O': 2}
#
# O*CY(COC(C)C*C)
# H   6C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 5, 'O': 2}
#
# O*CY(COC(C)*CC)
# H   6C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 5, 'O': 2}
#
# CJCY(CCC)
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# CCY(CJCC)
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# CCY(CCJC)
# H   7C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 4}
#
# C*CY(CCC)
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# CCY(C*CC)
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# CCY(CC*C)
# H   6C   4    0    0G   300.000  2500.0001000.000      1
# {'H': 6, 'C': 4}
#
# OJC(C)CCCHO
# C   5H   9O   2    0G   300.000  5000.000 1323.000    41
# {'H': 9, 'C': 5, 'O': 2}
#
# O*C*CCC(C)OJ
# C   5H   7O   2    0G   300.000  5000.000 1685.000    31
# {'H': 7, 'C': 5, 'O': 2}
#
# C*CC(*O)OCJC
# C   5H   7O   2    0G   300.000  5000.000 1404.000    31
# {'H': 7, 'C': 5, 'O': 2}
#
# CC*CCC(*O)OJ
# C   5H   7O   2    0G   300.000  5000.000 1374.000    31
# {'H': 7, 'C': 5, 'O': 2}
#
# C*CC(C)OC*JO
# C   5H   7O   2    0G   300.000  5000.000 1376.000    41
# {'H': 7, 'C': 5, 'O': 2}
#
# O*CY(COC*CCJ)
# C   4H   3O   2    0G   300.000  5000.000 1437.000    01
# {'H': 3, 'C': 4, 'O': 2}
#
# O*CY(COCJ(C)C*C)
# C   5H   5O   2    0G   300.000  5000.000 1397.000    11
# {'H': 5, 'C': 5, 'O': 2}
#
# O*CY(COC*(C)CCJ)
# C   5H   5O   2    0G   300.000  5000.000 1512.000    11
# {'H': 5, 'C': 5, 'O': 2}
#
# gvlr-2(3oh)
# C   5H   7O   3    0G   300.000  5000.000 1407.000    21
# {'H': 7, 'C': 5, 'O': 3}
#
# gvlr-4(3oh)
# C   5H   7O   3    0G   300.000  5000.000 1427.000    21
# {'H': 7, 'C': 5, 'O': 3}
#
# O*CY(COCJC(OH)C)
# C   4H   5O   3    0G   300.000  5000.000 1411.000    11
# {'H': 5, 'C': 4, 'O': 3}
#
# O*CJC*CC(*O)C
# C   5H   5O   2    0G   300.000  5000.000 1398.000    11
# {'H': 5, 'C': 5, 'O': 2}
#
# O*C*CC*C(C)OJ
# C   5H   5O   2    0G   300.000  5000.000 1392.000    11
# {'H': 5, 'C': 5, 'O': 2}
#
# O*C*CC*COJ
# C   4H   3O   2    0G   300.000  5000.000 1402.000    01
# {'H': 3, 'C': 4, 'O': 2}
#
# CHCHCHO
# C   3H   3O   1    0G   300.000  5000.000 1394.000    01
# {'H': 3, 'C': 3, 'O': 1}
#
# CHCHCOCH3
# C   4H   5O   1    0G   300.000  5000.000 1395.000    11
# {'H': 5, 'C': 4, 'O': 1}
#
# HCOHCO
# H   2O   2C   2     G    300.00   5000.00 1000.00      1
# {'H': 2, 'C': 2, 'O': 2}
#
# O*CY(COCJ(C)CC)
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}
#
# C*COC(*O)CCJ
# H   7C   5O   2    0G   300.000  2500.0001000.000      1
# {'H': 7, 'C': 5, 'O': 2}

# %%
entries_dict
# Out:
# {'A-C3H4': {'C': 3, 'H': 4},
#  'A-C3H5': {'C': 3, 'H': 5},
#  'A-C3H5CHO': {'C': 4, 'H': 6, 'O': 1},
#  'A-C3H5OOH': {'C': 3, 'H': 6, 'O': 2},
#  'A1-C6H6': {'C': 6, 'H': 6},
#  'ACEOH': {'C': 2, 'H': 4, 'O': 2},
#  'AR': {'AR': 1},
#  'C': {'C': 1},
#  'C#CCCJ': {'C': 4, 'H': 5},
#  'C#CCJC': {'C': 4, 'H': 5},
#  'C*C(C)OC(*O)CJ': {'C': 5, 'H': 7, 'O': 2},
#  'C*C(C)OH': {'C': 3, 'H': 6, 'O': 1},
#  'C*C(OH)2': {'C': 2, 'H': 4, 'O': 2},
#  'C*CC(*O)OCJC': {'C': 5, 'H': 7, 'O': 2},
#  'C*CC(C)OC*JO': {'C': 5, 'H': 7, 'O': 2},
#  'C*CC(C)OCJ(*O)': {'C': 5, 'H': 7, 'O': 2},
#  'C*CC(C)OH': {'C': 4, 'H': 8, 'O': 1},
#  'C*CC2J': {'C': 4, 'H': 7},
#  'C*CCC(*O)OH': {'C': 4, 'H': 6, 'O': 2},
#  'C*CCC*C(OH)2': {'C': 5, 'H': 8, 'O': 2},
#  'C*CCC*C*O': {'C': 5, 'H': 6, 'O': 1},
#  'C*CCCC(*O)OH': {'C': 5, 'H': 8, 'O': 2},
#  'C*CCCC(*O)OJ': {'C': 5, 'H': 7, 'O': 2},
#  'C*CCCC(OJ)OH': {'C': 5, 'H': 9, 'O': 2},
#  'C*CCCCHO': {'C': 5, 'H': 8, 'O': 1},
#  'C*CCCCJ(OH)2': {'C': 5, 'H': 9, 'O': 2},
#  'C*CCCJC(*O)OH': {'C': 5, 'H': 7, 'O': 2},
#  'C*COC(*O)CCJ': {'C': 5, 'H': 7, 'O': 2},
#  'C*COC(*O)CJ': {'C': 4, 'H': 5, 'O': 2},
#  'C*COH': {'C': 2, 'H': 4, 'O': 1},
#  'C*CY(CCC)': {'C': 4, 'H': 6},
#  'C-C*CCJCC(*O)OH': {'C': 5, 'H': 7, 'O': 2},
#  'C-CC*CC': {'C': 4, 'H': 8},
#  'C-CC*CCC(*O)OH': {'C': 5, 'H': 8, 'O': 2},
#  'C-CC*CCJ': {'C': 4, 'H': 7},
#  'C-CCC*CC(*O)OH': {'C': 5, 'H': 8, 'O': 2},
#  'C2C*CJ': {'C': 4, 'H': 7},
#  'C2C*O': {'C': 3, 'H': 6, 'O': 1},
#  'C2CJOH': {'C': 3, 'H': 7, 'O': 1},
#  'C2COC(*C)OJ': {'C': 5, 'H': 9, 'O': 2},
#  'C2COCY(CJCO)': {'C': 5, 'H': 9, 'O': 2},
#  'C2COJ': {'C': 3, 'H': 7, 'O': 1},
#  'C2H': {'C': 2, 'H': 1},
#  'C2H2': {'C': 2, 'H': 2},
#  'C2H3': {'C': 2, 'H': 3},
#  'C2H3CHO': {'C': 3, 'H': 4, 'O': 1},
#  'C2H3CO': {'C': 3, 'H': 3, 'O': 1},
#  'C2H3COCH3': {'C': 4, 'H': 6, 'O': 1},
#  'C2H3O1-2': {'C': 2, 'H': 3, 'O': 1},
#  'C2H4': {'C': 2, 'H': 4},
#  'C2H4O1-2': {'C': 2, 'H': 4, 'O': 1},
#  'C2H4O2H': {'C': 2, 'H': 5, 'O': 2},
#  'C2H4OH': {'C': 2, 'H': 5, 'O': 1},
#  'C2H5': {'C': 2, 'H': 5},
#  'C2H5CHCO': {'C': 4, 'H': 6, 'O': 1},
#  'C2H5CHO': {'C': 3, 'H': 6, 'O': 1},
#  'C2H5CO': {'C': 3, 'H': 5, 'O': 1},
#  'C2H5COC2H3': {'C': 5, 'H': 8, 'O': 1},
#  'C2H5COC2H4P': {'C': 5, 'H': 9, 'O': 1},
#  'C2H5COC2H5': {'C': 5, 'H': 10, 'O': 1},
#  'C2H5COCH2': {'C': 4, 'H': 7, 'O': 1},
#  'C2H5COCH3': {'C': 4, 'H': 8, 'O': 1},
#  'C2H5O': {'C': 2, 'H': 5, 'O': 1},
#  'C2H5O2': {'C': 2, 'H': 5, 'O': 2},
#  'C2H5O2H': {'C': 2, 'H': 6, 'O': 2},
#  'C2H5OH': {'C': 2, 'H': 6, 'O': 1},
#  'C2H6': {'C': 2, 'H': 6},
#  'C2JCCCC(*O)OH': {'C': 6, 'H': 11, 'O': 2},
#  'C2JCOC(*C)OH': {'C': 5, 'H': 9, 'O': 2},
#  'C2JCOH': {'C': 3, 'H': 7, 'O': 1},
#  'C2O': {'C': 2, 'O': 1},
#  'C3H2': {'C': 3, 'H': 2},
#  'C3H2O': {'C': 3, 'H': 2, 'O': 1},
#  'C3H3': {'C': 3, 'H': 3},
#  'C3H52-1J3OOH': {'C': 3, 'H': 7, 'O': 4},
#  'C3H5O': {'C': 3, 'H': 5, 'O': 1},
#  'C3H6': {'C': 3, 'H': 6},
#  'C3H6CHO-1': {'C': 4, 'H': 7, 'O': 1},
#  'C3H6CHO-2': {'C': 4, 'H': 7, 'O': 1},
#  'C3H6CHO-3': {'C': 4, 'H': 7, 'O': 1},
#  'C3H6COCH3-1': {'C': 5, 'H': 9, 'O': 1},
#  'C3H6COCH3-2': {'C': 5, 'H': 9, 'O': 1},
#  'C3H6O1-2': {'C': 3, 'H': 6, 'O': 1},
#  'C3H6O1-3': {'C': 3, 'H': 6, 'O': 1},
#  'C3H6OH': {'C': 3, 'H': 7, 'O': 1},
#  'C3H6OOH1-2': {'C': 3, 'H': 7, 'O': 2},
#  'C3H6OOH1-2O2': {'C': 3, 'H': 7, 'O': 4},
#  'C3H6OOH1-3': {'C': 3, 'H': 7, 'O': 2},
#  'C3H6OOH1-3O2': {'C': 3, 'H': 7, 'O': 4},
#  'C3H6OOH2-1': {'C': 3, 'H': 7, 'O': 2},
#  'C3H8': {'C': 3, 'H': 8},
#  'C3KET12': {'C': 3, 'H': 6, 'O': 3},
#  'C3KET13': {'C': 3, 'H': 6, 'O': 3},
#  'C4H': {'C': 4, 'H': 1},
#  'C4H10': {'C': 4, 'H': 10},
#  'C4H2': {'C': 4, 'H': 2},
#  'C4H4': {'C': 4, 'H': 4},
#  'C4H6': {'C': 4, 'H': 6},
#  'C4H71-1': {'C': 4, 'H': 7},
#  'C4H71-2': {'C': 4, 'H': 7},
#  'C4H71-3': {'C': 4, 'H': 7},
#  'C4H71-4': {'C': 4, 'H': 7},
#  'C4H7O': {'C': 4, 'H': 7, 'O': 1},
#  'C4H8-1': {'C': 4, 'H': 8},
#  'C4H8-2': {'C': 4, 'H': 8},
#  'C4H8CHO-1': {'C': 5, 'H': 9, 'O': 1},
#  'C4H8CHO-2': {'C': 5, 'H': 9, 'O': 1},
#  'C4H8CHO-3': {'C': 5, 'H': 9, 'O': 1},
#  'C4H8CHO-4': {'C': 5, 'H': 9, 'O': 1},
#  'C4H8O1-2': {'C': 4, 'H': 8, 'O': 1},
#  'C4H8O1-3': {'C': 4, 'H': 8, 'O': 1},
#  'C4H8OH-1O2': {'C': 4, 'H': 9, 'O': 3},
#  'C4H8OH-2O2': {'C': 4, 'H': 9, 'O': 3},
#  'C4H8OOH1-2': {'C': 4, 'H': 9, 'O': 2},
#  'C4H8OOH1-3': {'C': 4, 'H': 9, 'O': 2},
#  'C4H8OOH1-3O2': {'C': 4, 'H': 9, 'O': 4},
#  'C5H10-1': {'C': 5, 'H': 10},
#  'C5H10-2': {'C': 5, 'H': 10},
#  'C5H10O1-3': {'C': 5, 'H': 10, 'O': 1},
#  'C5H10O1-4': {'C': 5, 'H': 10, 'O': 1},
#  'C5H10OH-1': {'C': 5, 'H': 11, 'O': 1},
#  'C5H10OOH1-2': {'C': 5, 'H': 11, 'O': 2},
#  'C5H10OOH1-3': {'C': 5, 'H': 11, 'O': 2},
#  'C5H10OOH1-3O2': {'C': 5, 'H': 11, 'O': 4},
#  'C5H10OOH1-4': {'C': 5, 'H': 11, 'O': 2},
#  'C5H11-1': {'C': 5, 'H': 11},
#  'C5H11-2': {'C': 5, 'H': 11},
#  'C5H11O-1': {'C': 5, 'H': 11, 'O': 1},
#  'C5H11O2-1': {'C': 5, 'H': 11, 'O': 2},
#  'C5H11O2H-1': {'C': 5, 'H': 12, 'O': 2},
#  'C5H81-3': {'C': 5, 'H': 8},
#  'C5H81-4': {'C': 5, 'H': 8},
#  'C5H91-3': {'C': 5, 'H': 9},
#  'C5H91-4': {'C': 5, 'H': 9},
#  'C5H91-5': {'C': 5, 'H': 9},
#  'C5H92-4': {'C': 5, 'H': 9},
#  'C5H92-5': {'C': 5, 'H': 9},
#  'C5H9O1-3': {'C': 5, 'H': 9, 'O': 1},
#  'C6H101-3': {'C': 6, 'H': 10},
#  'C6H101-4': {'C': 6, 'H': 10},
#  'C6H101-5': {'C': 6, 'H': 10},
#  'C6H101OOH3-5': {'C': 6, 'H': 11, 'O': 2},
#  'C6H101OOH4-3': {'C': 6, 'H': 11, 'O': 2},
#  'C6H101OOH5-3': {'C': 6, 'H': 11, 'O': 2},
#  'C6H101OOH6-3': {'C': 6, 'H': 11, 'O': 2},
#  'C6H111-3': {'C': 6, 'H': 11},
#  'C6H111-4': {'C': 6, 'H': 11},
#  'C6H111-5': {'C': 6, 'H': 11},
#  'C6H111-6': {'C': 6, 'H': 11},
#  'C6H111O2-3': {'C': 6, 'H': 11, 'O': 2},
#  'C6H111O2-4': {'C': 6, 'H': 11, 'O': 2},
#  'C6H111O2-5': {'C': 6, 'H': 11, 'O': 2},
#  'C6H111O2-6': {'C': 6, 'H': 11, 'O': 2},
#  'C6H111O2H-4': {'C': 6, 'H': 12, 'O': 2},
#  'C6H112O2-1': {'C': 6, 'H': 11, 'O': 2},
#  'C6H11O1-3': {'C': 6, 'H': 11, 'O': 1},
#  'C6H12-1': {'C': 6, 'H': 12},
#  'C6H12-2': {'C': 6, 'H': 12},
#  'C6H12-3': {'C': 6, 'H': 12},
#  'C6H12O1-3': {'C': 6, 'H': 12, 'O': 1},
#  'C6H12O1-4': {'C': 6, 'H': 12, 'O': 1},
#  'C6H12OH-1': {'C': 6, 'H': 13, 'O': 1},
#  'C6H12OOH1-2': {'C': 6, 'H': 13, 'O': 2},
#  'C6H12OOH1-3': {'C': 6, 'H': 13, 'O': 2},
#  'C6H12OOH1-3O2': {'C': 6, 'H': 13, 'O': 4},
#  'C6H12OOH1-4': {'C': 6, 'H': 13, 'O': 2},
#  'C6H13-1': {'C': 6, 'H': 13},
#  'C6H13-2': {'C': 6, 'H': 13},
#  'C6H13-3': {'C': 6, 'H': 13},
#  'C6H13O-1': {'C': 6, 'H': 13, 'O': 1},
#  'C6H13O2-1': {'C': 6, 'H': 13, 'O': 2},
#  'C6H2': {'C': 6, 'H': 2},
#  'C8H2': {'C': 8, 'H': 2},
#  'CC#C': {'C': 3, 'H': 4},
#  'CC#CC': {'C': 4, 'H': 6},
#  'CC#CCJ': {'C': 4, 'H': 5},
#  'CC(*O)CCCHO': {'C': 5, 'H': 8, 'O': 2},
#  'CC(*O)CCCJ(*O)': {'C': 5, 'H': 7, 'O': 2},
#  'CC(OH)CC*C*O': {'C': 5, 'H': 8, 'O': 2},
#  'CC(OH)CCCJ(*O)': {'C': 5, 'H': 9, 'O': 2},
#  'CC(OH)CCJCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CC(OH)CJCCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CC(OJ)CCCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CC*C*C': {'C': 4, 'H': 6},
#  'CC*CCC(*O)OJ': {'C': 5, 'H': 7, 'O': 2},
#  'CC*CJC': {'C': 4, 'H': 7},
#  'CCC#C': {'C': 4, 'H': 6},
#  'CCC(*C)OCHO': {'C': 5, 'H': 8, 'O': 2},
#  'CCC(C)(OJ)HCO': {'C': 5, 'H': 9, 'O': 2},
#  'CCC(C)OCJ(*O)': {'C': 5, 'H': 9, 'O': 2},
#  'CCC(CJ)OCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CCCC*C*O': {'C': 5, 'H': 8, 'O': 1},
#  'CCCCC(*O)OJ': {'C': 5, 'H': 9, 'O': 2},
#  'CCCCJC(*O)OH': {'C': 5, 'H': 9, 'O': 2},
#  'CCCJ(C)OCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CCCJCC(*O)OH': {'C': 5, 'H': 9, 'O': 2},
#  'CCCJCCC(*O)OH': {'C': 6, 'H': 11, 'O': 2},
#  'CCCJCOCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CCJ(OH)CCCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CCJC(C)OCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CCJCCC(*O)OH': {'C': 5, 'H': 9, 'O': 2},
#  'CCJCCOCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CCJOCHO': {'C': 3, 'H': 5, 'O': 2},
#  'CCY(C*CC)': {'C': 4, 'H': 6},
#  'CCY(CC*C)': {'C': 4, 'H': 6},
#  'CCY(CCJC)': {'C': 4, 'H': 7},
#  'CCY(CJCC)': {'C': 4, 'H': 7},
#  'CCY(COCJOCC)': {'C': 5, 'H': 9, 'O': 2},
#  'CH': {'C': 1, 'H': 1},
#  'CH2CCH2OH': {'C': 3, 'H': 5, 'O': 1},
#  'CH2CH2CHO': {'C': 3, 'H': 5, 'O': 1},
#  'CH2CH2COCH3': {'C': 4, 'H': 7, 'O': 1},
#  'CH2CHO': {'C': 2, 'H': 3, 'O': 1},
#  'CH2CO': {'C': 2, 'H': 2, 'O': 1},
#  'CH2O': {'C': 1, 'H': 2, 'O': 1},
#  'CH2OH': {'C': 1, 'H': 3, 'O': 1},
#  'CH3': {'C': 1, 'H': 3},
#  'CH3CHCO': {'C': 3, 'H': 4, 'O': 1},
#  'CH3CHCOCH3': {'C': 4, 'H': 7, 'O': 1},
#  'CH3CHO': {'C': 2, 'H': 4, 'O': 1},
#  'CH3CHOH': {'C': 2, 'H': 5, 'O': 1},
#  'CH3CO': {'C': 2, 'H': 3, 'O': 1},
#  'CH3CO2': {'C': 2, 'H': 3, 'O': 2},
#  'CH3CO3': {'C': 2, 'H': 3, 'O': 3},
#  'CH3CO3H': {'C': 2, 'H': 4, 'O': 3},
#  'CH3COCH2': {'C': 3, 'H': 5, 'O': 1},
#  'CH3COCH2O': {'C': 3, 'H': 5, 'O': 2},
#  'CH3COCH2O2': {'C': 3, 'H': 5, 'O': 3},
#  'CH3COCH2O2H': {'C': 3, 'H': 6, 'O': 3},
#  'CH3O': {'C': 1, 'H': 3, 'O': 1},
#  'CH3O2': {'C': 1, 'H': 3, 'O': 2},
#  'CH3O2H': {'C': 1, 'H': 4, 'O': 2},
#  'CH3OCH2': {'C': 2, 'H': 5, 'O': 1},
#  'CH3OCH3': {'C': 2, 'H': 6, 'O': 1},
#  'CH3OCO': {'C': 2, 'H': 3, 'O': 2},
#  'CH3OH': {'C': 1, 'H': 4, 'O': 1},
#  'CH4': {'C': 1, 'H': 4},
#  'CHCHCHO': {'C': 3, 'H': 3, 'O': 1},
#  'CHCHCOCH3': {'C': 4, 'H': 5, 'O': 1},
#  'CJ(*O)OH': {'C': 1, 'H': 1, 'O': 2},
#  'CJC(*O)OH': {'C': 2, 'H': 3, 'O': 2},
#  'CJC(OH)CCCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CJCC(*O)C': {'C': 4, 'H': 7, 'O': 1},
#  'CJCC(*O)OH': {'C': 3, 'H': 5, 'O': 2},
#  'CJCC(C)OCHO': {'C': 5, 'H': 9, 'O': 2},
#  'CJCC(C)OH': {'C': 4, 'H': 9, 'O': 1},
#  'CJCCCC(*O)OH': {'C': 5, 'H': 9, 'O': 2},
#  'CJCY(CCC)': {'C': 4, 'H': 7},
#  'CO': {'C': 1, 'O': 1},
#  'CO2': {'C': 1, 'O': 2},
#  'CY(C*CC)': {'C': 3, 'H': 4},
#  'CY(C*CCC)': {'C': 4, 'H': 6},
#  'CY(CJCC)': {'C': 3, 'H': 5},
#  'CY(CJCCC)': {'C': 4, 'H': 7},
#  'GVL': {'C': 5, 'H': 8, 'O': 2},
#  'GVLR-2': {'C': 5, 'H': 7, 'O': 2},
#  'GVLR-3': {'C': 5, 'H': 7, 'O': 2},
#  'GVLR-4': {'C': 5, 'H': 7, 'O': 2},
#  'GVLR-5': {'C': 5, 'H': 7, 'O': 2},
#  'H': {'H': 1},
#  'H2': {'H': 2},
#  'H2C2': {'C': 2, 'H': 2},
#  'H2O': {'H': 2, 'O': 1},
#  'H2O2': {'H': 2, 'O': 2},
#  'HC(*O)OCJ': {'C': 2, 'H': 3, 'O': 2},
#  'HCCO': {'C': 2, 'H': 1, 'O': 1},
#  'HCCOH': {'C': 2, 'H': 2, 'O': 1},
#  'HCO': {'C': 1, 'H': 1, 'O': 1},
#  'HCOHCO': {'C': 2, 'H': 2, 'O': 2},
#  'HE': {'HE': 1},
#  'HO2': {'H': 1, 'O': 2},
#  'HO2CHO': {'C': 1, 'H': 2, 'O': 3},
#  'HOC3H6O2': {'C': 3, 'H': 7, 'O': 3},
#  'HOCH2O': {'C': 1, 'H': 3, 'O': 2},
#  'HOCHO': {'C': 1, 'H': 2, 'O': 2},
#  'HOCY(C*CCC(C)O)': {'C': 5, 'H': 8, 'O': 2},
#  'HOCY(CJOC(C)CC)': {'C': 5, 'H': 9, 'O': 2},
#  'I-C3H7': {'C': 3, 'H': 7},
#  'I-C3H7O': {'C': 3, 'H': 7, 'O': 1},
#  'I-C3H7O2': {'C': 3, 'H': 7, 'O': 2},
#  'I-C4H3': {'C': 4, 'H': 3},
#  'I-C4H5': {'C': 4, 'H': 5},
#  'JOCY(COC(C)CC)': {'C': 5, 'H': 9, 'O': 2},
#  'MVOX': {'C': 6, 'H': 10, 'O': 1},
#  'N-C3H7': {'C': 3, 'H': 7},
#  'N-C3H7CHO': {'C': 4, 'H': 8, 'O': 1},
#  'N-C3H7CO': {'C': 4, 'H': 7, 'O': 1},
#  'N-C3H7COCH2': {'C': 5, 'H': 9, 'O': 1},
#  'N-C3H7COCH3': {'C': 5, 'H': 10, 'O': 1},
#  'N-C3H7O': {'C': 3, 'H': 7, 'O': 1},
#  'N-C3H7O2': {'C': 3, 'H': 7, 'O': 2},
#  'N-C3H7O2H': {'C': 3, 'H': 8, 'O': 2},
#  'N-C4H3': {'C': 4, 'H': 3},
#  'N-C4H5': {'C': 4, 'H': 5},
#  'N-C4H9CHO': {'C': 5, 'H': 10, 'O': 1},
#  'N-C4H9CO': {'C': 5, 'H': 9, 'O': 1},
#  'N-C7H16': {'C': 7, 'H': 16},
#  'N2': {'N': 2},
#  'NC3H7COC2H4P': {'C': 6, 'H': 11, 'O': 1},
#  'NC4KET13': {'C': 4, 'H': 8, 'O': 3},
#  'NC5KET13': {'C': 5, 'H': 10, 'O': 3},
#  'NC6KET13': {'C': 6, 'H': 12, 'O': 3},
#  'O': {'O': 1},
#  'O*C*CC*C(C)OJ': {'C': 5, 'H': 5, 'O': 2},
#  'O*C*CC*COJ': {'C': 4, 'H': 3, 'O': 2},
#  'O*C*CCC(C)OJ': {'C': 5, 'H': 7, 'O': 2},
#  'O*CJC*CC(*O)C': {'C': 5, 'H': 5, 'O': 2},
#  'O*CY(CCO)': {'C': 2, 'H': 2, 'O': 2},
#  'O*CY(COC(C)*CC)': {'C': 5, 'H': 6, 'O': 2},
#  'O*CY(COC(C)C*C)': {'C': 5, 'H': 6, 'O': 2},
#  'O*CY(COC*(C)CCJ)': {'C': 5, 'H': 5, 'O': 2},
#  'O*CY(COC*CC)': {'C': 4, 'H': 4, 'O': 2},
#  'O*CY(COC*CCJ)': {'C': 4, 'H': 3, 'O': 2},
#  'O*CY(COCJ(C)C*C)': {'C': 5, 'H': 5, 'O': 2},
#  'O*CY(COCJ(C)CC)': {'C': 5, 'H': 7, 'O': 2},
#  'O*CY(COCJC(OH)C)': {'C': 4, 'H': 5, 'O': 3},
#  'O*CY(COCJCC)': {'C': 4, 'H': 5, 'O': 2},
#  'O2': {'O': 2},
#  'O2C2H4OH': {'C': 2, 'H': 5, 'O': 3},
#  'O2C5H10OH-1': {'C': 5, 'H': 11, 'O': 3},
#  'O2C6H12OH-1': {'C': 6, 'H': 13, 'O': 3},
#  'O2CHO': {'C': 1, 'H': 1, 'O': 3},
#  'OCHO': {'C': 1, 'H': 1, 'O': 2},
#  'OH': {'H': 1, 'O': 1},
#  'OHCCCCHO': {'C': 4, 'H': 6, 'O': 2},
#  'OHCCCCJ(*O)': {'C': 4, 'H': 5, 'O': 2},
#  'OJC(C)CCCHO': {'C': 5, 'H': 9, 'O': 2},
#  'P-C2H4COC2H3': {'C': 5, 'H': 7, 'O': 1},
#  'P-C3H4': {'C': 3, 'H': 4},
#  'P-C4H8OH': {'C': 4, 'H': 9, 'O': 1},
#  'P-C4H9': {'C': 4, 'H': 9},
#  'P-C4H9O': {'C': 4, 'H': 9, 'O': 1},
#  'P-C4H9O2': {'C': 4, 'H': 9, 'O': 2},
#  'P-C4H9O2H': {'C': 4, 'H': 10, 'O': 2},
#  'S-C3H5': {'C': 3, 'H': 5},
#  'S-C4H8OH': {'C': 4, 'H': 9, 'O': 1},
#  'S-C4H9': {'C': 4, 'H': 9},
#  'S-CH2': {'C': 1, 'H': 2},
#  'T-C*CCJCC(*O)OH': {'C': 5, 'H': 7, 'O': 2},
#  'T-C3H5': {'C': 3, 'H': 5},
#  'T-CC*CC': {'C': 4, 'H': 8},
#  'T-CC*CCC(*O)OH': {'C': 5, 'H': 8, 'O': 2},
#  'T-CC*CCJ': {'C': 4, 'H': 7},
#  'T-CCC*CC(*O)OH': {'C': 5, 'H': 8, 'O': 2},
#  'T-CH2': {'C': 1, 'H': 2},
#  'VTHF': {'C': 6, 'H': 10, 'O': 1},
#  'gvlr-2(3oh)': {'C': 5, 'H': 7, 'O': 3},
#  'gvlr-4(3oh)': {'C': 5, 'H': 7, 'O': 3}}

# %%
errors_dict
# Out:
# {'C2JCCCC(*O)OH': {'C': 6, 'H': 11, 'O': 2},
#  'CCCJCCC(*O)OH': {'C': 6, 'H': 11, 'O': 2},
#  'MVOX': {'C': 6, 'H': 10, 'O': 1},
#  'NC5KET13': {'C': 5, 'H': 10, 'O': 3},
#  'NC6KET13': {'C': 6, 'H': 12, 'O': 3},
#  'VTHF': {'C': 6, 'H': 10, 'O': 1}}
